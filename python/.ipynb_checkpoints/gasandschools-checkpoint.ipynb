# %% [markdown]
# # Gas Station Relocation Analysis in Boston, MA

# %% [markdown]
# ## Installations

# %%
# !pip install pysal openpyxl geopandas pandas h3 geopy osmnx
# Out:
# Collecting pysal
#   Downloading pysal-25.7-py3-none-any.whl.metadata (15 kB)
# Collecting openpyxl
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: geopandas in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (1.1.1)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (2.3.2)
# Collecting h3
#   Downloading h3-4.3.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (18 kB)
# Collecting geopy
#   Downloading geopy-2.4.1-py3-none-any.whl.metadata (6.8 kB)
# Collecting osmnx
#   Downloading osmnx-2.0.6-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: beautifulsoup4>=4.10 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (4.13.5)
# Requirement already satisfied: numpy>=1.22 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (2.0.1)
# Requirement already satisfied: packaging>=22 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (25.0)
# Requirement already satisfied: platformdirs>=2.0.2 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (4.3.7)
# Requirement already satisfied: requests>=2.27 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (2.32.5)
# Requirement already satisfied: scipy>=1.8 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (1.16.2)
# Requirement already satisfied: shapely>=2.0.1 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (2.1.1)
# Requirement already satisfied: scikit-learn>=1.1 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (1.7.2)
# Collecting libpysal>=4.13.0 (from pysal)
#   Downloading libpysal-4.13.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting access>=1.1.9 (from pysal)
#   Downloading access-1.1.9-py3-none-any.whl.metadata (2.4 kB)
# Collecting esda>=2.7.1 (from pysal)
#   Downloading esda-2.8.0-py3-none-any.whl.metadata (2.0 kB)
# Collecting giddy>=2.3.6 (from pysal)
#   Downloading giddy-2.3.6-py3-none-any.whl.metadata (6.3 kB)
# Collecting inequality>=1.1.2 (from pysal)
#   Downloading inequality-1.1.2-py3-none-any.whl.metadata (3.9 kB)
# Collecting pointpats>=2.5.1 (from pysal)
#   Downloading pointpats-2.5.2-py3-none-any.whl.metadata (4.7 kB)
# Collecting segregation>=2.5.2 (from pysal)
#   Downloading segregation-2.5.2-py3-none-any.whl.metadata (2.2 kB)
# Collecting spaghetti>=1.7.6 (from pysal)
#   Downloading spaghetti-1.7.6-py3-none-any.whl.metadata (12 kB)
# Collecting mgwr>=2.2.1 (from pysal)
#   Downloading mgwr-2.2.1-py3-none-any.whl.metadata (1.5 kB)
# Collecting momepy>=0.10.0 (from pysal)
#   Downloading momepy-0.10.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting spglm>=1.1.0 (from pysal)
#   Downloading spglm-1.1.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting spint>=1.0.7 (from pysal)
#   Downloading spint-1.0.7.tar.gz (28 kB)
#   Preparing metadata (setup.py) ... done
# Collecting spreg>=1.8.3 (from pysal)
#   Downloading spreg-1.8.3-py3-none-any.whl.metadata (1.7 kB)
# Collecting tobler>=0.12.1 (from pysal)
#   Downloading tobler-0.12.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: mapclassify>=2.10.0 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pysal) (2.10.0)
# Collecting splot>=1.1.7 (from pysal)
#   Downloading splot-1.1.7-py3-none-any.whl.metadata (8.9 kB)
# Collecting spopt>=0.7.0 (from pysal)
#   Downloading spopt-0.7.0-py3-none-any.whl.metadata (10 kB)
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pyogrio>=0.7.2 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from geopandas) (0.10.0)
# Requirement already satisfied: pyproj>=3.5.0 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pandas) (2025.2)
# Collecting geographiclib<3,>=1.52 (from geopy)
#   Downloading geographiclib-2.1-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: networkx>=2.5 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from osmnx) (3.5)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from beautifulsoup4>=4.10->pysal) (2.5)
# Requirement already satisfied: typing-extensions>=4.0.0 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from beautifulsoup4>=4.10->pysal) (4.15.0)
# Collecting quantecon>=0.7 (from giddy>=2.3.6->pysal)
#   Downloading quantecon-0.10.1-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: matplotlib>=3.8 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from inequality>=1.1.2->pysal) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from matplotlib>=3.8->inequality>=1.1.2->pysal) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from matplotlib>=3.8->inequality>=1.1.2->pysal) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from matplotlib>=3.8->inequality>=1.1.2->pysal) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from matplotlib>=3.8->inequality>=1.1.2->pysal) (1.4.8)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from matplotlib>=3.8->inequality>=1.1.2->pysal) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from matplotlib>=3.8->inequality>=1.1.2->pysal) (3.2.0)
# Collecting tqdm>=4.65 (from momepy>=0.10.0->pysal)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from pyogrio>=0.7.2->geopandas) (2025.8.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting numba>=0.49.0 (from quantecon>=0.7->giddy>=2.3.6->pysal)
#   Downloading numba-0.62.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.8 kB)
# Collecting sympy (from quantecon>=0.7->giddy>=2.3.6->pysal)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.49.0->quantecon>=0.7->giddy>=2.3.6->pysal)
#   Downloading llvmlite-0.45.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (4.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from requests>=2.27->pysal) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from requests>=2.27->pysal) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from requests>=2.27->pysal) (2.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from scikit-learn>=1.1->pysal) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from scikit-learn>=1.1->pysal) (3.5.0)
# Collecting deprecation (from segregation>=2.5.2->pysal)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Collecting seaborn (from segregation>=2.5.2->pysal)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting rtree>=1.0 (from spaghetti>=1.7.6->pysal)
#   Downloading rtree-1.4.1-py3-none-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting pulp>=2.8 (from spopt>=0.7.0->pysal)
#   Downloading pulp-3.3.0-py3-none-any.whl.metadata (8.4 kB)
# Collecting rasterio (from tobler>=0.12.1->pysal)
#   Downloading rasterio-1.4.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (9.1 kB)
# Collecting statsmodels (from tobler>=0.12.1->pysal)
#   Downloading statsmodels-0.14.5-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.5 kB)
# Collecting rasterstats (from tobler>=0.12.1->pysal)
#   Downloading rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# Collecting affine (from rasterio->tobler>=0.12.1->pysal)
#   Downloading affine-2.4.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: attrs in /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages (from rasterio->tobler>=0.12.1->pysal) (24.3.0)
# Collecting click>=4.0 (from rasterio->tobler>=0.12.1->pysal)
#   Downloading click-8.3.0-py3-none-any.whl.metadata (2.6 kB)
# Collecting cligj>=0.5 (from rasterio->tobler>=0.12.1->pysal)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Collecting click-plugins (from rasterio->tobler>=0.12.1->pysal)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting fiona (from rasterstats->tobler>=0.12.1->pysal)
#   Downloading fiona-1.10.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (56 kB)
# Collecting simplejson (from rasterstats->tobler>=0.12.1->pysal)
#   Downloading simplejson-3.20.2-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.4 kB)
# Collecting patsy>=0.5.6 (from statsmodels->tobler>=0.12.1->pysal)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->quantecon>=0.7->giddy>=2.3.6->pysal)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading pysal-25.7-py3-none-any.whl (17 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading h3-4.3.1-cp311-cp311-macosx_11_0_arm64.whl (800 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.9/800.9 kB 17.3 MB/s  0:00:00
# Downloading geopy-2.4.1-py3-none-any.whl (125 kB)
# Downloading geographiclib-2.1-py3-none-any.whl (40 kB)
# Downloading osmnx-2.0.6-py3-none-any.whl (101 kB)
# Downloading access-1.1.9-py3-none-any.whl (21 kB)
# Downloading esda-2.8.0-py3-none-any.whl (157 kB)
# Downloading giddy-2.3.6-py3-none-any.whl (61 kB)
# Downloading inequality-1.1.2-py3-none-any.whl (21 kB)
# Downloading libpysal-4.13.0-py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 36.9 MB/s  0:00:00
# Downloading mgwr-2.2.1-py3-none-any.whl (47 kB)
# Downloading momepy-0.10.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 51.5 MB/s  0:00:00
# Downloading pointpats-2.5.2-py3-none-any.whl (63 kB)
# Downloading quantecon-0.10.1-py3-none-any.whl (325 kB)
# Downloading numba-0.62.1-cp311-cp311-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 46.6 MB/s  0:00:00
# Downloading llvmlite-0.45.1-cp311-cp311-macosx_11_0_arm64.whl (37.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 49.4 MB/s  0:00:00 eta 0:00:01
# Downloading segregation-2.5.2-py3-none-any.whl (141 kB)
# Downloading spaghetti-1.7.6-py3-none-any.whl (53 kB)
# Downloading rtree-1.4.1-py3-none-macosx_11_0_arm64.whl (436 kB)
# Downloading spglm-1.1.0-py3-none-any.whl (41 kB)
# Downloading splot-1.1.7-py3-none-any.whl (39 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading spopt-0.7.0-py3-none-any.whl (248 kB)
# Downloading pulp-3.3.0-py3-none-any.whl (16.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 55.4 MB/s  0:00:00 eta 0:00:01
# Downloading spreg-1.8.3-py3-none-any.whl (389 kB)
# Downloading tobler-0.12.1-py3-none-any.whl (28 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading rasterio-1.4.3-cp311-cp311-macosx_14_0_arm64.whl (18.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.8/18.8 MB 38.8 MB/s  0:00:00 eta 0:00:01
# Downloading click-8.3.0-py3-none-any.whl (107 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading affine-2.4.0-py3-none-any.whl (15 kB)
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading rasterstats-0.20.0-py3-none-any.whl (17 kB)
# Downloading fiona-1.10.1-cp311-cp311-macosx_11_0_arm64.whl (14.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 38.6 MB/s  0:00:00eta 0:00:01
# Downloading simplejson-3.20.2-cp311-cp311-macosx_11_0_arm64.whl (75 kB)
# Downloading statsmodels-0.14.5-cp311-cp311-macosx_11_0_arm64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 22.4 MB/s  0:00:00 eta 0:00:01
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 43.6 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 28.3 MB/s  0:00:00
# Building wheels for collected packages: spint
#   DEPRECATION: Building 'spint' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'spint'. Discussion can be found at https://github.com/pypa/pip/issues/6334
#   Building wheel for spint (setup.py) ... done
#   Created wheel for spint: filename=spint-1.0.7-py3-none-any.whl size=31448 sha256=c029a224f19baf598c72dfd03458e783b0148bbf339a9ca06a51b6820c2f944c
#   Stored in directory: /Users/sangam/Library/Caches/pip/wheels/32/dc/2e/400caaa67e697355772a82b77b8c2ac7cd61633f595c477fd8
# Successfully built spint
# Installing collected packages: mpmath, tqdm, sympy, simplejson, rtree, pulp, patsy, llvmlite, h3, geographiclib, et-xmlfile, deprecation, click, affine, openpyxl, numba, geopy, cligj, click-plugins, statsmodels, seaborn, rasterio, quantecon, fiona, rasterstats, osmnx, libpysal, access, tobler, spreg, segregation, pointpats, momepy, inequality, esda, spglm, spaghetti, giddy, spopt, splot, spint, mgwr, pysal
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43/43 [pysal]m38/43 [spopt]ats]s]
# Successfully installed access-1.1.9 affine-2.4.0 click-8.3.0 click-plugins-1.1.1.2 cligj-0.7.2 deprecation-2.1.0 esda-2.8.0 et-xmlfile-2.0.0 fiona-1.10.1 geographiclib-2.1 geopy-2.4.1 giddy-2.3.6 h3-4.3.1 inequality-1.1.2 libpysal-4.13.0 llvmlite-0.45.1 mgwr-2.2.1 momepy-0.10.0 mpmath-1.3.0 numba-0.62.1 openpyxl-3.1.5 osmnx-2.0.6 patsy-1.0.2 pointpats-2.5.2 pulp-3.3.0 pysal-25.7 quantecon-0.10.1 rasterio-1.4.3 rasterstats-0.20.0 rtree-1.4.1 seaborn-0.13.2 segregation-2.5.2 simplejson-3.20.2 spaghetti-1.7.6 spglm-1.1.0 spint-1.0.7 splot-1.1.7 spopt-0.7.0 spreg-1.8.3 statsmodels-0.14.5 sympy-1.14.0 tobler-0.12.1 tqdm-4.67.1

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# We need the boston map. As we are going to analize schools and gas stations we must omit the water bodies. A good option is:
#
#
# *   https://www.mass.gov/info-details/massgis-data-municipalities
#
# You will select the shapefile for Boston from there. The file returned will be a zip, which I have saved on GitHub from where I read it:

# %%
import geopandas as gpd

#filez="https://github.com/DACSS-Spatial/data_forSpatial/raw/refs/heads/main/BOSTON/GISDATA.TOWNSSURVEY_POLYM.zip"
filez = "https://github.com/Spatial-Data-Analytics-DACSS-690D/Gas-Station-Relocation-Analysis/raw/refs/heads/main/Data/BOSTON/GISDATA.TOWNSSURVEY_POLYM.zip"
boston=gpd.read_file(filez)
boston.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   town        1 non-null      object
#  1   town_id     1 non-null      int32
#  2   type        1 non-null      object
#  3   county      1 non-null      object
#  4   fips_stco   1 non-null      int32
#  5   fourcolor   1 non-null      int32
#  6   pop1960     1 non-null      int32
#  7   pop1970     1 non-null      int32
#  8   pop1980     1 non-null      int32
#  9   pop1990     1 non-null      int32
#  10  pop2000     1 non-null      int32
#  11  pop2010     1 non-null      int32
#  12  pop2020     1 non-null      int32
#  13  popch10_20  1 non-null      int32
#  14  area_acres  1 non-null      float64
#  15  area_sqmi   1 non-null      float64
#  16  geometry    1 non-null      geometry
# dtypes: float64(2), geometry(1), int32(11), object(3)
# memory usage: 224.0+ bytes

# %%
boston
# Out:
#      town  town_id type   county  fips_stco  fourcolor  pop1960  pop1970  \
# 0  BOSTON       35    C  SUFFOLK      25025          1   697197   641071
#
#    pop1980  pop1990  pop2000  pop2010  pop2020  popch10_20   area_acres  \
# 0   562994   574283   588957   617594   675647       58053  32104.34973
#
#    area_sqmi                                           geometry
# 0   50.15997  MULTIPOLYGON (((235056.153 904531.255, 235060....

# %%
boston.crs
# Out:
# <Projected CRS: EPSG:26986>
# Name: NAD83 / Massachusetts Mainland
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - Massachusetts onshore - counties of Barnstable; Berkshire; Bristol; Essex; Franklin; Hampden; Hampshire; Middlesex; Norfolk; Plymouth; Suffolk; Worcester.
# - bounds: (-73.5, 41.46, -69.86, 42.89)
# Coordinate Operation:
# - name: SPCS83 Massachusetts Mainland zone (meter)
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %% [markdown]
# ### Crowdsourced data pre processing

# %% [markdown]
# Now we need the schools and gas stations.

# %%
# Get gas stations in Boston
import osmnx as ox

stations = ox.features_from_place("Boston, Massachusetts, USA",
                                tags={'amenity': 'fuel'})
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:451: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)

# %%
stations.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 55 entries, ('node', np.int64(1547613299)) to ('way', np.int64(997511426))
# Data columns (total 33 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   geometry              55 non-null     geometry
#  1   amenity               55 non-null     object
#  2   addr:city             21 non-null     object
#  3   addr:housenumber      26 non-null     object
#  4   addr:postcode         23 non-null     object
#  5   addr:state            20 non-null     object
#  6   addr:street           26 non-null     object
#  7   brand                 35 non-null     object
#  8   brand:wikidata        35 non-null     object
#  9   name                  45 non-null     object
#  10  opening_hours         7 non-null      object
#  11  compressed_air        9 non-null      object
#  12  source                4 non-null      object
#  13  ref                   7 non-null      object
#  14  website               14 non-null     object
#  15  shop                  1 non-null      object
#  16  self_service          10 non-null     object
#  17  check_date            5 non-null      object
#  18  description           2 non-null      object
#  19  phone                 5 non-null      object
#  20  internet_access       2 non-null      object
#  21  payment:mastercard    1 non-null      object
#  22  payment:visa          1 non-null      object
#  23  brand:website         1 non-null      object
#  24  building              23 non-null     object
#  25  fuel:diesel           3 non-null      object
#  26  fuel:gasoline         1 non-null      object
#  27  layer                 8 non-null      object
#  28  opening_hours:signed  1 non-null      object
#  29  operator              1 non-null      object
#  30  building:levels       1 non-null      object
#  31  fuel:octane_95        1 non-null      object
#  32  type                  1 non-null      object
# dtypes: geometry(1), object(32)
# memory usage: 17.0+ KB

# %% [markdown]
# OSM gave us stations unprojecte so lets project those.

# %%
stations.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
stations
# Out:
#                                                                geometry  \
# element  id
# node     1547613299                          POINT (-71.11921 42.27983)
#          1915267811                          POINT (-71.12623 42.35823)
#          1975943661                          POINT (-71.05651 42.32059)
#          2086266695                          POINT (-71.15482 42.29539)
#          2108017693                          POINT (-71.15664 42.26192)
#          2108018346                          POINT (-71.16118 42.25828)
#          2108019392                          POINT (-71.15166 42.28766)
#          2299726166                           POINT (-71.11332 42.3174)
#          4119910813                          POINT (-71.11833 42.29594)
#          4456008435                          POINT (-71.03919 42.37176)
#          4456091896                          POINT (-71.02777 42.37965)
#          4456091915                          POINT (-71.00924 42.38557)
#          5012538664                          POINT (-71.04636 42.28384)
#          7049179057                          POINT (-71.13113 42.28346)
#          7711828654                          POINT (-71.09536 42.34499)
#          7779156553                          POINT (-71.03967 42.38287)
#          7801604967                          POINT (-71.06318 42.37186)
#          8911740730                          POINT (-71.12258 42.24965)
#          9155798164                          POINT (-71.11235 42.33173)
#          9301640141                          POINT (-71.12988 42.35254)
#          9307561244                             POINT (-71.08 42.38247)
#          9826872460                          POINT (-71.13487 42.35426)
#          11512786470                         POINT (-71.11478 42.27676)
#          12636225024                         POINT (-71.15399 42.34196)
#          12850165667                         POINT (-71.14183 42.34454)
#          13205043192                          POINT (-71.07321 42.2714)
#          13205071184                          POINT (-71.1061 42.27145)
#          13227205788                         POINT (-71.06912 42.27873)
# relation 13500843     POLYGON ((-71.02803 42.36628, -71.02801 42.366...
# way      29520631     POLYGON ((-71.02751 42.37897, -71.02755 42.379...
#          29613466     POLYGON ((-71.0565 42.3211, -71.05662 42.32109...
#          29622378     POLYGON ((-71.05527 42.33449, -71.05539 42.334...
#          29648812     POLYGON ((-71.07091 42.33124, -71.07092 42.331...
#          29650844     POLYGON ((-71.08125 42.33912, -71.08128 42.339...
#          29677198     POLYGON ((-71.12761 42.23623, -71.1277 42.2362...
#          29778889     POLYGON ((-71.14953 42.35589, -71.1497 42.3559...
#          29779289     POLYGON ((-71.16721 42.35018, -71.16746 42.350...
#          29804770     POLYGON ((-71.05959 42.31409, -71.05971 42.314...
#          29805421     POLYGON ((-71.07033 42.33183, -71.07046 42.331...
#          29806343     POLYGON ((-71.09524 42.3456, -71.09529 42.3456...
#          29829809     POLYGON ((-71.11445 42.31527, -71.11447 42.315...
#          29831768     POLYGON ((-71.04201 42.28608, -71.04206 42.286...
#          29833313     POLYGON ((-71.04847 42.29561, -71.04855 42.295...
#          29887927     POLYGON ((-71.11912 42.27979, -71.11931 42.279...
#          29934128     POLYGON ((-71.1142 42.31577, -71.1143 42.3158,...
#          29934166     POLYGON ((-71.10606 42.30727, -71.10635 42.307...
#          29941823     POLYGON ((-71.10334 42.33343, -71.10368 42.333...
#          29946760     POLYGON ((-71.05551 42.34139, -71.05548 42.341...
#          212124454    POLYGON ((-71.06475 42.32535, -71.06441 42.325...
#          212129122    POLYGON ((-71.11089 42.32082, -71.11083 42.320...
#          350480325    POLYGON ((-71.13054 42.36304, -71.13037 42.363...
#          405514198    POLYGON ((-71.08174 42.34024, -71.08186 42.340...
#          644451331    POLYGON ((-71.04768 42.28384, -71.04806 42.283...
#          723203623    POLYGON ((-71.13169 42.237, -71.13175 42.23701...
#          997511426    POLYGON ((-71.16262 42.29367, -71.16258 42.293...
#
#                      amenity          addr:city addr:housenumber  \
# element  id
# node     1547613299     fuel                NaN              NaN
#          1915267811     fuel            Allston              219
#          1975943661     fuel         Dorchester              888
#          2086266695     fuel                NaN              NaN
#          2108017693     fuel                NaN              NaN
#          2108018346     fuel       West Roxbury             5315
#          2108019392     fuel       West Roxbury             1779
#          2299726166     fuel                NaN              NaN
#          4119910813     fuel                NaN             3875
#          4456008435     fuel                NaN              NaN
#          4456091896     fuel                NaN              NaN
#          4456091915     fuel                NaN              NaN
#          5012538664     fuel                NaN              NaN
#          7049179057     fuel                NaN              NaN
#          7711828654     fuel             Boston             1250
#          7779156553     fuel                NaN              NaN
#          7801604967     fuel        Charlestown                1
#          8911740730     fuel                NaN              NaN
#          9155798164     fuel      Jamaica Plain              914
#          9301640141     fuel            Allston              100
#          9307561244     fuel        Charlestown              123
#          9826872460     fuel                NaN              434
#          11512786470    fuel                NaN              NaN
#          12636225024    fuel                NaN              NaN
#          12850165667    fuel                NaN              NaN
#          13205043192    fuel                NaN              NaN
#          13205071184    fuel                NaN              NaN
#          13227205788    fuel                NaN              NaN
# relation 13500843       fuel                NaN               45
# way      29520631       fuel             Boston              331
#          29613466       fuel         Dorchester              874
#          29622378       fuel             Boston              151
#          29648812       fuel             Boston              895
#          29650844       fuel             Boston              785
#          29677198       fuel                NaN              NaN
#          29778889       fuel           Brighton              195
#          29779289       fuel                NaN              NaN
#          29804770       fuel                NaN              NaN
#          29805421       fuel                NaN              NaN
#          29806343       fuel             Boston              200
#          29829809       fuel             Boston              581
#          29831768       fuel                NaN              NaN
#          29833313       fuel                NaN              NaN
#          29887927       fuel                NaN              NaN
#          29934128       fuel                NaN              NaN
#          29934166       fuel      Jamaica Plain             3440
#          29941823       fuel                NaN             1600
#          29946760       fuel                NaN               79
#          212124454      fuel                NaN              NaN
#          212129122      fuel                NaN              NaN
#          350480325      fuel                NaN              NaN
#          405514198      fuel             Boston              584
#          644451331      fuel  Dorchester Center              710
#          723203623      fuel             Boston             1820
#          997511426      fuel                NaN              NaN
#
#                      addr:postcode addr:state           addr:street  \
# element  id
# node     1547613299            NaN        NaN                   NaN
#          1915267811          02134         MA      Cambridge Street
#          1975943661          02125         MA     Dorchester Avenue
#          2086266695            NaN        NaN                   NaN
#          2108017693            NaN        NaN                   NaN
#          2108018346          02132         MA     Washington Street
#          2108019392          02132         MA         Centre Street
#          2299726166            NaN        NaN                   NaN
#          4119910813          02131        NaN     Washington Street
#          4456008435            NaN        NaN                   NaN
#          4456091896            NaN        NaN                   NaN
#          4456091915            NaN        NaN                   NaN
#          5012538664            NaN        NaN                   NaN
#          7049179057            NaN        NaN                   NaN
#          7711828654          02215         MA       Boylston Street
#          7779156553            NaN        NaN                   NaN
#          7801604967          02129         MA     Rutherford Avenue
#          8911740730            NaN        NaN                   NaN
#          9155798164          02130         MA     Huntington Avenue
#          9301640141          02134         MA       Brighton Avenue
#          9307561244          02129         MA      Cambridge Street
#          9826872460            NaN        NaN      Cambridge Street
#          11512786470           NaN        NaN                   NaN
#          12636225024           NaN        NaN                   NaN
#          12850165667           NaN        NaN                   NaN
#          13205043192           NaN        NaN                   NaN
#          13205071184           NaN        NaN                   NaN
#          13227205788           NaN        NaN                   NaN
# relation 13500843            02128        NaN    Transportation Way
# way      29520631            02128         MA     Bennington Street
#          29613466            02125         MA     Dorchester Avenue
#          29622378            02127         MA     Old Colony Avenue
#          29648812            02118         MA  Massachusetts Avenue
#          29650844            02118         MA        Tremont Street
#          29677198              NaN        NaN                   NaN
#          29778889            02135         MA         Market Street
#          29779289              NaN        NaN                   NaN
#          29804770              NaN        NaN                   NaN
#          29805421              NaN        NaN                   NaN
#          29806343            02215         MA        Ipswich Street
#          29829809            02130        NaN         Centre Street
#          29831768              NaN        NaN                   NaN
#          29833313              NaN        NaN                   NaN
#          29887927              NaN        NaN                   NaN
#          29934128              NaN        NaN                   NaN
#          29934166            02130         MA     Washington Street
#          29941823              NaN        NaN        Tremont Street
#          29946760              NaN        NaN         West Broadway
#          212124454             NaN        NaN                   NaN
#          212129122             NaN        NaN                   NaN
#          350480325             NaN        NaN                   NaN
#          405514198           02118         MA       Columbus Avenue
#          644451331           02124         MA    Gallivan Boulevard
#          723203623           02136         MA      Hyde Park Avenue
#          997511426             NaN        NaN                   NaN
#
#                                  brand brand:wikidata                name  \
# element  id
# node     1547613299                NaN            NaN                 NaN
#          1915267811              Shell     Q110716465               Shell
#          1975943661               Gulf       Q5617505  Columbia Road Gulf
#          2086266695              Shell     Q110716465               Shell
#          2108017693                NaN            NaN                 NaN
#          2108018346           Speedway       Q7575683            Speedway
#          2108019392           Speedway       Q7575683            Speedway
#          2299726166                NaN            NaN              JP Oil
#          4119910813                NaN            NaN        Emporium Gas
#          4456008435              Shell     Q110716465               Shell
#          4456091896              Mobil     Q109676002               Mobil
#          4456091915                NaN            NaN                 NaN
#          5012538664               Gulf       Q5617505                Gulf
#          7049179057                NaN            NaN                 NaN
#          7711828654             Sunoco       Q1423218              Sunoco
#          7779156553              Mobil     Q109676002               Mobil
#          7801604967              Shell     Q110716465               Shell
#          8911740730                 BP        Q152057                  BP
#          9155798164              Citgo       Q2974437               Citgo
#          9301640141           Speedway       Q7575683            Speedway
#          9307561244           Speedway       Q7575683            Speedway
#          9826872460             Irving       Q1673286              Irving
#          11512786470       Stop & Shop       Q3658429         Stop & Shop
#          12636225024  Cumberland Farms       Q1143685    Cumberland Farms
#          12850165667             Mobil     Q109676002               Mobil
#          13205043192            Sunoco       Q1423218              Sunoco
#          13205071184            Sunoco       Q1423218              Sunoco
#          13227205788            Sunoco       Q1423218              Sunoco
# relation 13500843                Shell        Q154950      Shell - Nouria
# way      29520631                   BP        Q152057                  BP
#          29613466             Speedway       Q7575683            Speedway
#          29622378             Speedway       Q7575683            Speedway
#          29648812               Sunoco       Q1423218              Sunoco
#          29650844                 Gulf       Q5617505                Gulf
#          29677198                Mobil     Q109676002               Mobil
#          29778889                 Gulf       Q5617505                Gulf
#          29779289                  NaN            NaN   Oak Square Sunoco
#          29804770                  NaN            NaN              US Gas
#          29805421                  NaN            NaN                 NaN
#          29806343                Shell     Q110716465               Shell
#          29829809                  NaN            NaN   Gibbs Gas Station
#          29831768                  NaN            NaN                 NaN
#          29833313                Citgo       Q2974437               Citgo
#          29887927                  NaN            NaN                 NaN
#          29934128                  NaN            NaN              JP Gas
#          29934166                  NaN            NaN       Stan Hatoff's
#          29941823                  NaN            NaN                 NaN
#          29946760                  NaN            NaN         Southie Gas
#          212124454         Stop & Shop       Q3658429     Stop & Shop Gas
#          212129122                 NaN            NaN                 NaN
#          350480325                 NaN            NaN              Nouria
#          405514198               Shell     Q110716465               Shell
#          644451331            Speedway       Q7575683            Speedway
#          723203623                 NaN            NaN    Roger's Services
#          997511426                 NaN            NaN                 NaN
#
#                       ...               brand:website building fuel:diesel  \
# element  id           ...
# node     1547613299   ...                         NaN      NaN         NaN
#          1915267811   ...                         NaN      NaN         NaN
#          1975943661   ...                         NaN      NaN         NaN
#          2086266695   ...                         NaN      NaN         NaN
#          2108017693   ...                         NaN      NaN         NaN
#          2108018346   ...                         NaN      NaN         NaN
#          2108019392   ...                         NaN      NaN         NaN
#          2299726166   ...                         NaN      NaN         NaN
#          4119910813   ...                         NaN      NaN         NaN
#          4456008435   ...                         NaN      NaN         NaN
#          4456091896   ...                         NaN      NaN         NaN
#          4456091915   ...                         NaN      NaN         NaN
#          5012538664   ...                         NaN      NaN         NaN
#          7049179057   ...                         NaN      NaN         NaN
#          7711828654   ...                         NaN      NaN         NaN
#          7779156553   ...                         NaN      NaN         NaN
#          7801604967   ...                         NaN      NaN         NaN
#          8911740730   ...                         NaN      NaN         NaN
#          9155798164   ...                         NaN      NaN         NaN
#          9301640141   ...                         NaN      NaN         NaN
#          9307561244   ...                         NaN      NaN         NaN
#          9826872460   ...  https://www.irvingoil.com/      NaN         NaN
#          11512786470  ...                         NaN      NaN         NaN
#          12636225024  ...                         NaN      NaN         NaN
#          12850165667  ...                         NaN      NaN         NaN
#          13205043192  ...                         NaN      NaN         NaN
#          13205071184  ...                         NaN      NaN         NaN
#          13227205788  ...                         NaN      NaN         NaN
# relation 13500843     ...                         NaN     roof         NaN
# way      29520631     ...                         NaN      yes         NaN
#          29613466     ...                         NaN     roof         yes
#          29622378     ...                         NaN     roof         NaN
#          29648812     ...                         NaN     roof         yes
#          29650844     ...                         NaN      yes         NaN
#          29677198     ...                         NaN     roof         NaN
#          29778889     ...                         NaN      NaN         NaN
#          29779289     ...                         NaN      yes         NaN
#          29804770     ...                         NaN      yes         NaN
#          29805421     ...                         NaN     roof         NaN
#          29806343     ...                         NaN      NaN         NaN
#          29829809     ...                         NaN      yes         NaN
#          29831768     ...                         NaN      yes         NaN
#          29833313     ...                         NaN      yes         NaN
#          997511426             NaN   NaN                  NaN      NaN
#
#                      building:levels fuel:octane_95          type
# element  id
# node     1547613299              NaN            NaN           NaN
#          1915267811              NaN            NaN           NaN
#          1975943661              NaN            NaN           NaN
#          2086266695              NaN            NaN           NaN
#          2108017693              NaN            NaN           NaN
#          2108018346              NaN            NaN           NaN
#          2108019392              NaN            NaN           NaN
#          2299726166              NaN            NaN           NaN
#          4119910813              NaN            NaN           NaN
#          4456008435              NaN            NaN           NaN
#          4456091896              NaN            NaN           NaN
#          4456091915              NaN            NaN           NaN
#          5012538664              NaN            NaN           NaN
#          7049179057              NaN            NaN           NaN
#          7711828654              NaN            NaN           NaN
#          7779156553              NaN            NaN           NaN
#          7801604967              NaN            NaN           NaN
#          8911740730              NaN            NaN           NaN
#          9155798164              NaN            NaN           NaN
#          9301640141              NaN            NaN           NaN
#          9307561244              NaN            NaN           NaN
#          9826872460              NaN            NaN           NaN
#          11512786470             NaN            NaN           NaN
#          12636225024             NaN            NaN           NaN
#          12850165667             NaN            NaN           NaN
#          13205043192             NaN            NaN           NaN
#          13205071184             NaN            NaN           NaN
#          13227205788             NaN            NaN           NaN
# relation 13500843                NaN            NaN  multipolygon
# way      29520631                NaN            NaN           NaN
#          29613466                NaN            NaN           NaN
#          29622378                NaN            NaN           NaN
#          29648812                NaN            NaN           NaN
#          29650844                NaN            NaN           NaN
#          29677198                NaN            NaN           NaN
#          29778889                NaN            NaN           NaN
#          29779289                NaN            NaN           NaN
#          29804770                NaN            NaN           NaN
#          29805421                NaN            NaN           NaN
#          29806343                  1            NaN           NaN
#          29829809                NaN            NaN           NaN
#          29831768                NaN            NaN           NaN
#          29833313                NaN            NaN           NaN
#          29887927                NaN            NaN           NaN
#          29934128                NaN            NaN           NaN
#          29934166                NaN            NaN           NaN
#          29941823                NaN            NaN           NaN
#          29946760                NaN            yes           NaN
#          212124454               NaN            NaN           NaN
#          212129122               NaN            NaN           NaN
#          350480325               NaN            NaN           NaN
#          405514198               NaN            NaN           NaN
#          644451331               NaN            NaN           NaN
#          723203623               NaN            NaN           NaN
#          997511426               NaN            NaN           NaN
#
# [55 rows x 33 columns]

# %% [markdown]
# Here, we facing problem of multi-indexing. Lets fix it.

# %%
stations.index
# Out:
# MultiIndex([(    'node',  1547613299),
#             (    'node',  1915267811),
#             (    'node',  1975943661),
#             (    'node',  2086266695),
#             (    'node',  2108017693),
#             (    'node',  2108018346),
#             (    'node',  2108019392),
#             (    'node',  2299726166),
#             (    'node',  4119910813),
#             (    'node',  4456008435),
#             (    'node',  4456091896),
#             (    'node',  4456091915),
#             (    'node',  5012538664),
#             (    'node',  7049179057),
#             (    'node',  7711828654),
#             (    'node',  7779156553),
#             (    'node',  7801604967),
#             (    'node',  8911740730),
#             (    'node',  9155798164),
#             (    'node',  9301640141),
#             (    'node',  9307561244),
#             (    'node',  9826872460),
#             (    'node', 11512786470),
#             (    'node', 12636225024),
#             (    'node', 12850165667),
#             (    'node', 13205043192),
#             (    'node', 13205071184),
#             (    'node', 13227205788),
#             ('relation',    13500843),
#             (     'way',    29520631),
#             (     'way',    29613466),
#             (     'way',    29622378),
#             (     'way',    29648812),
#             (     'way',    29650844),
#             (     'way',    29677198),
#             (     'way',    29778889),
#             (     'way',    29779289),
#             (     'way',    29804770),
#             (     'way',    29805421),
#             (     'way',    29806343),
#             (     'way',    29829809),
#             (     'way',    29831768),
#             (     'way',    29833313),
#             (     'way',    29887927),
#             (     'way',    29934128),
#             (     'way',    29934166),
#             (     'way',    29941823),
#             (     'way',    29946760),
#             (     'way',   212124454),
#             (     'way',   212129122),
#             (     'way',   350480325),
#             (     'way',   405514198),
#             (     'way',   644451331),
#             (     'way',   723203623),
#             (     'way',   997511426)],
#            names=['element', 'id'])

# %% [markdown]
# Some formatting is needed at this stage:
#
# - This will put current indexes back into the data, and numbers will appear:

# %%
stations.reset_index(drop=False,inplace=True)
stations.head()
# Out:
#   element          id                    geometry amenity   addr:city  \
# 0    node  1547613299  POINT (-71.11921 42.27983)    fuel         NaN
# 1    node  1915267811  POINT (-71.12623 42.35823)    fuel     Allston
# 2    node  1975943661  POINT (-71.05651 42.32059)    fuel  Dorchester
# 3    node  2086266695  POINT (-71.15482 42.29539)    fuel         NaN
# 4    node  2108017693  POINT (-71.15664 42.26192)    fuel         NaN
#
#   addr:housenumber addr:postcode addr:state        addr:street  brand  ...  \
# 0              NaN           NaN        NaN                NaN    NaN  ...
# 1              219         02134         MA   Cambridge Street  Shell  ...
# 2              888         02125         MA  Dorchester Avenue   Gulf  ...
# 3              NaN           NaN        NaN                NaN  Shell  ...
# 4              NaN           NaN        NaN                NaN    NaN  ...
#
#   brand:website building fuel:diesel fuel:gasoline layer opening_hours:signed  \
# 0           NaN      NaN         NaN           NaN   NaN                  NaN
# 1           NaN      NaN         NaN           NaN   NaN                  NaN
# 2           NaN      NaN         NaN           NaN   NaN                  NaN
# 3           NaN      NaN         NaN           NaN   NaN                  NaN
# 4           NaN      NaN         NaN           NaN   NaN                  NaN
#
#   operator building:levels fuel:octane_95 type
# 0      NaN             NaN            NaN  NaN
# 1      NaN             NaN            NaN  NaN
# 2      NaN             NaN            NaN  NaN
# 3      NaN             NaN            NaN  NaN
# 4      NaN             NaN            NaN  NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# - Keep some columns:

# %%
colsToKeep=['element','name','geometry']
fuelBoston=stations[colsToKeep].copy()

# %% [markdown]
# - Reproject the data:

# %%
Boston_crs = "EPSG:26986"

fuelBoston = fuelBoston.to_crs(Boston_crs)

# %% [markdown]
# - Review:

# %%
fuelBoston.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   element   55 non-null     object
#  1   name      45 non-null     object
#  2   geometry  55 non-null     geometry
# dtypes: geometry(1), object(2)
# memory usage: 1.4+ KB

# %% [markdown]
# - From above, columns **name** of the gas station has missing values. We should rename those missing values:

# %%
fuelBoston.fillna({'name':'Unknown'},inplace=True)

# %% [markdown]
# - We usually use the names as row index. But row index should not have duplicates. Since several 'names' are the same (_Unknown_), we have to create new names:

# %%
fuelBoston.index.astype(str)+"_"+fuelBoston.name
# Out:
# 0                0_Unknown
# 1                  1_Shell
# 2     2_Columbia Road Gulf
# 3                  3_Shell
# 4                4_Unknown
# 5               5_Speedway
# 6               6_Speedway
# 7                 7_JP Oil
# 8           8_Emporium Gas
# 9                  9_Shell
# 10                10_Mobil
# 11              11_Unknown
# 12                 12_Gulf
# 13              13_Unknown
# 14               14_Sunoco
# 15                15_Mobil
# 16                16_Shell
# 17                   17_BP
# 18                18_Citgo
# 19             19_Speedway
# 20             20_Speedway
# 21               21_Irving
# 22          22_Stop & Shop
# 23     23_Cumberland Farms
# 24                24_Mobil
# 25               25_Sunoco
# 26               26_Sunoco
# 27               27_Sunoco
# 28       28_Shell - Nouria
# 29                   29_BP
# 30             30_Speedway
# 31             31_Speedway
# 32               32_Sunoco
# 33                 33_Gulf
# 34                34_Mobil
# 35                 35_Gulf
# 36    36_Oak Square Sunoco
# 37               37_US Gas
# 38              38_Unknown
# 39                39_Shell
# 40    40_Gibbs Gas Station
# 41              41_Unknown
# 42                42_Citgo
# 43              43_Unknown
# 44               44_JP Gas
# 45        45_Stan Hatoff's
# 46              46_Unknown
# 47          47_Southie Gas
# 48      48_Stop & Shop Gas
# 49              49_Unknown
# 50               50_Nouria
# 51                51_Shell
# 52             52_Speedway
# 53     53_Roger's Services
# 54              54_Unknown
# dtype: object

# %% [markdown]
# Then,

# %%
fuelBoston['newname']=fuelBoston.index.astype(str)+"_"+fuelBoston.name
fuelBoston.set_index('newname',inplace=True)
fuelBoston.drop(columns=['name'],inplace=True)
fuelBoston.head()
# Out:
#                      element                       geometry
# newname
# 0_Unknown               node   POINT (231409.205 892220.97)
# 1_Shell                 node   POINT (230791.53 900926.709)
# 2_Columbia Road Gulf    node  POINT (236556.832 896773.514)
# 3_Shell                 node  POINT (228464.872 893936.856)
# 4_Unknown               node   POINT (228329.637 890218.87)

# %% [markdown]
# See that **nodes** are points, **ways** are lines or simple shapes built from points, and **relations** are conceptual containers that group any of the other elements to represent complex features.
#
# Let me compare with the geometries available:

# %%
#import pandas as pd

#pd.crosstab(fuelBoston.element,fuelBoston.geometry.geom_type, margins=True)

# %% [markdown]
# This is the 'relation' we have:

# %%
#original data
#stations[stations.element=='relation']

# %%
#fuelBoston[fuelBoston.element=='relation'].plot()

# %% [markdown]
# Let's get the schools:

# %%
# Get schools in Boston
schools = ox.features_from_place("Boston, Massachusetts, USA",
                                tags={'amenity': 'school'})
schools.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 271 entries, ('node', np.int64(257493925)) to ('way', np.int64(1417025273))
# Data columns (total 99 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   geometry                 271 non-null    geometry
#  1   addr:city                185 non-null    object
#  2   addr:housenumber         197 non-null    object
#  3   addr:postcode            188 non-null    object
#  4   addr:state               166 non-null    object
#  5   addr:street              198 non-null    object
#  6   amenity                  271 non-null    object
#  7   attribution              116 non-null    object
#  8   gnis:feature_id          127 non-null    object
#  9   jurisdiction             1 non-null      object
#  10  name                     264 non-null    object
#  11  old_name                 12 non-null     object
#  12  source_url               27 non-null     object
#  13  grades                   147 non-null    object
#  14  massgis:school_id        134 non-null    object
#  15  phone                    164 non-null    object
#  16  website                  66 non-null     object
#  17  source:url               87 non-null     object
#  18  type                     125 non-null    object
#  19  education                118 non-null    object
#  20  ele                      89 non-null     object
#  21  email                    9 non-null      object
#  22  wikidata                 68 non-null     object
#  23  charge                   2 non-null      object
#  24  check_date               13 non-null     object
#  25  fax                      6 non-null      object
#  26  fee                      2 non-null      object
#  27  operator                 44 non-null     object
#  28  operator:type            38 non-null     object
#  29  religion                 17 non-null     object
#  30  school                   2 non-null      object
#  31  start_date               3 non-null      object
#  32  alt_name                 8 non-null      object
#  33  operator:short           27 non-null     object
#  34  operator:wikidata        27 non-null     object
#  35  operator:wikipedia       7 non-null      object
#  36  wheelchair               2 non-null      object
#  37  level                    1 non-null      object
#  38  contact:fax              2 non-null      object
#  39  contact:phone            3 non-null      object
#  40  denomination             5 non-null      object
#  41  wikipedia                7 non-null      object
#  42  craft                    1 non-null      object
#  43  opening_hours            3 non-null      object
#  44  description              1 non-null      object
#  45  building                 43 non-null     object
#  46  source                   10 non-null     object
#  47  building:levels          9 non-null      object
#  48  roof:shape               4 non-null      object
#  49  roof:levels              3 non-null      object
#  50  access                   3 non-null      object
#  51  building:material        1 non-null      object
#  52  contact:facebook         2 non-null      object
#  53  roof:colour              1 non-null      object
#  54  owner                    4 non-null      object
#  55  addr:suburb              1 non-null      object
#  56  addr:country             1 non-null      object
#  57  short_name               3 non-null      object
#  58  area                     1 non-null      object
#  59  massgis:ARTICLE97        2 non-null      object
#  60  massgis:ASSESS_ACR       2 non-null      object
#  61  massgis:ATT_DATE         2 non-null      object
#  62  massgis:DCAM_ID          2 non-null      object
#  63  massgis:DEED_ACRES       2 non-null      object
#  64  massgis:EOEAINVOLV       2 non-null      object
#  65  massgis:FEESYM           2 non-null      object
#  66  massgis:FEE_OWNER        2 non-null      object
#  67  massgis:FY_FUNDING       2 non-null      object
#  68  massgis:LEV_PROT         2 non-null      object
#  69  massgis:MANAGER          1 non-null      object
#  70  massgis:MANAGR_ABR       1 non-null      object
#  71  massgis:MANAGR_TYP       1 non-null      object
#  72  massgis:OS_DEED_BO       2 non-null      object
#  73  massgis:OS_DEED_PA       2 non-null      object
#  74  massgis:OS_ID            2 non-null      object
#  75  massgis:OWNER_ABRV       1 non-null      object
#  76  massgis:OWNER_TYPE       2 non-null      object
#  77  massgis:POLY_ID          2 non-null      object
#  78  massgis:PRIM_PURP        2 non-null      object
#  79  massgis:PUB_ACCESS       2 non-null      object
#  80  massgis:SITE_NAME        2 non-null      object
#  81  massgis:SOURCE_MAP       2 non-null      object
#  82  massgis:TOWN_ID          2 non-null      object
#  83  ownership                2 non-null      object
#  84  protected                1 non-null      object
#  85  contact:instagram        1 non-null      object
#  86  contact:twitter          1 non-null      object
#  87  facebook                 1 non-null      object
#  88  instagram                1 non-null      object
#  89  twitter                  1 non-null      object
#  90  max_age                  1 non-null      object
#  91  min_age                  1 non-null      object
#  92  official_name            2 non-null      object
#  93  name:etymology:wikidata  1 non-null      object
#  94  mascot                   1 non-null      object
#  95  note                     2 non-null      object
#  96  isced:level              1 non-null      object
#  97  wikipedia:en             1 non-null      object
#  98  office                   1 non-null      object
# dtypes: geometry(1), object(98)
# memory usage: 220.8+ KB
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:451: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)

# %% [markdown]
# Let's reformat this as we did before:

# %%
schools.reset_index(inplace=True)
schoolBoston=schools[['element','name','geometry']].copy()
schoolBoston.fillna({'name':'Unknown'},inplace=True)
schoolBoston['newname']=schoolBoston.index.astype(str)+"_"+schoolBoston.name
schoolBoston.set_index('newname',inplace=True)
schoolBoston.drop(columns=['name'],inplace=True)
schoolBoston = schoolBoston.to_crs(Boston_crs)
schoolBoston.head()
# Out:
#                                element                       geometry
# newname
# 0_Boston Police Academy           node  POINT (231587.542 888708.322)
# 1_Urban Science Academy           node   POINT (226876.32 892442.908)
# 2_Boston Middle School Academy    node  POINT (234181.887 894623.399)
# 3_Ralph Waldo Emerson School      node  POINT (235209.779 897088.628)
# 4_John Paul II Polish School      node  POINT (236451.673 897587.454)

# %% [markdown]
# See element vs geo:

# %%
#pd.crosstab(schoolBoston.element,schoolBoston.geometry.geom_type, margins=True)

# %%
#original data
#schools[(schools.element=='relation') & (schools.geometry.geom_type=='MultiPolygon')]

# %%
#schoolBoston[(schoolBoston.element=='relation') & (schoolBoston.geometry.geom_type=='MultiPolygon')].plot()

# %%
base=boston.explore(tiles='cartodbpositron',color='lightblue')
schoolBoston.explore(m=base,color='k')
fuelBoston.explore(m=base,color='red')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4cc8e341d8b59f82f61d54b4ea103e85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4cc8e341d8b59f82f61d54b4ea103e85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4cc8e341d8b59f82f61d54b4ea103e85 = L.map(
#                 &quot;map_4cc8e341d8b59f82f61d54b4ea103e85&quot;,
#                 {
#                     center: [42.312443937379925, -71.03004763692431],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_4cc8e341d8b59f82f61d54b4ea103e85);
#
#
#
#
#
#             var tile_layer_29510d5dd51c8a9b2c4d84eac551aa56 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_29510d5dd51c8a9b2c4d84eac551aa56.addTo(map_4cc8e341d8b59f82f61d54b4ea103e85);
#
#
#             map_4cc8e341d8b59f82f61d54b4ea103e85.fitBounds(
#                 [[42.22791089349467, -71.19125001787258], [42.396976981265176, -70.86884525597604]],
#                 {}
#             );
#
#
#         function geo_json_233eda80a418f9bb2dd4ee5a22cbcd5d_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;lightblue&quot;, &quot;fillColor&quot;: &quot;lightblue&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_233eda80a418f9bb2dd4ee5a22cbcd5d_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_233eda80a418f9bb2dd4ee5a22cbcd5d_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_233eda80a418f9bb2dd4ee5a22cbcd5d_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_233eda80a418f9bb2dd4ee5a22cbcd5d_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_233eda80a418f9bb2dd4ee5a22cbcd5d.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&qu

# %% [markdown]
# # Explore proximity:
#
#
# Let's compute a couple of distance matrices.
#
# - The distance among fuel stations

# %%
D_Matrix_fuel_fuel=fuelBoston.geometry.apply\
(lambda station: fuelBoston.geometry.distance(station))

D_Matrix_fuel_fuel
# Out:
# newname                  0_Unknown       1_Shell  2_Columbia Road Gulf  \
# newname
# 0_Unknown                 0.000000   8727.624383           6871.952298
# 1_Shell                8727.624383      0.000000           7105.472646
# 2_Columbia Road Gulf   6871.952298   7105.472646              0.000000
# 3_Shell                3407.837938   7366.911850           8574.756321
# 38_Unknown             1305.196059   5636.578385         11677.224480
# 39_Shell               1232.469961   7880.091938         12423.367160
# 40_Gibbs Gas Station   3848.394463   6472.680704          8791.488738
# 41_Unknown             6840.035148    527.066662          9185.184313
# 42_Citgo               5649.608963   1299.844196          9455.319276
# 43_Unknown             7381.139255   5874.971613          4854.781647
# 44_JP Gas              3801.815126   6503.202595          8859.476030
# 45_Stan Hatoff's       4156.095309   5440.365730          8078.630585
# 46_Unknown             1919.534927   7147.365057         10954.985526
# 47_Southie Gas         2152.064341   6407.946406         13178.545234
# 48_Stop & Shop Gas     2166.466056   4802.649318         11249.913892
# 49_Unknown             3215.252598   6602.411633          9457.153724
# 50_Nouria              4713.213296  11090.965884         13970.002980
# 51_Shell                  0.000000   6850.839417         12177.743477
# 52_Speedway            6850.839417      0.000000          8631.277174
# 53_Roger's Services   12177.743477   8631.277174             0.000000
# 54_Unknown             8426.955214   9495.674957          6774.030122
#
# newname                 54_Unknown
# newname
# 0_Unknown              3884.455796
# 1_Shell                7763.762976
# 2_Columbia Road Gulf   9232.804703
# 3_Shell                 658.507965
# 4_Unknown              3554.262419
# 5_Speedway             3926.944945
# 6_Speedway             1113.725238
# 7_JP Oil               4833.315836
# 8_Emporium Gas         3648.146781
# 9_Shell               13357.391330
# 10_Mobil              14642.056845
# 11_Unknown            16235.509285
# 12_Gulf                9637.124611
# 13_Unknown             2822.104558
# 14_Sunoco              7940.952850
# 15_Mobil              14159.960169
# 16_Shell              11930.508303
# 17_BP                  5892.929545
# 18_Citgo               5909.604358
# 19_Speedway            7064.944166
# 20_Speedway           11975.017791
# 21_Irving              7099.287570
# 22_Stop & Shop         4358.487272
# 23_Cumberland Farms    5403.780282
# 24_Mobil               5895.563544
# 25_Sunoco              7765.840492
# 26_Sunoco              5263.504147
# 27_Sunoco              7875.392121
# 28_Shell - Nouria     13688.856790
# 29_BP                 14608.953930
# 30_Speedway            9242.510328
# 31_Speedway            9931.765835
# 32_Sunoco              8606.792932
# 33_Gulf                8384.420360
# 34_Mobil               6978.812604
# 35_Gulf                6987.698294
# 36_Oak Square Sunoco   6282.310325
# 37_US Gas              8772.412913
# 38_Unknown             8689.988860
# 39_Shell               7996.031926
# 40_Gibbs Gas Station   4615.151116
# 41_Unknown             9964.219382
# 42_Citgo               9396.104273
# 43_Unknown             3875.610294
# 44_JP Gas              4669.995649
# 45_Stan Hatoff's       4872.370145
# 46_Unknown             6563.627078
# 47_Southie Gas        10286.773023
# 48_Stop & Shop Gas     8790.959887
# 49_Unknown             5212.560101
# 50_Nouria              8118.685181
# 51_Shell               8426.955214
# 52_Speedway            9495.674957
# 53_Roger's Services    6774.030122
# 54_Unknown                0.000000
#
# [55 rows x 55 columns]

# %% [markdown]
# From here, we can compute the minimal distance among those gas stations:

# %%
D_Matrix_fuel_fuel.replace(0,None,inplace=True) # avoid the zero
D_Matrix_fuel_fuel.min(axis=1).sort_values().head(10)
# Out:
# newname
# 40_Gibbs Gas Station    48.487191
# 44_JP Gas               48.487191
# 30_Speedway             55.729518
# 2_Columbia Road Gulf    55.729518
# 32_Sunoco               66.650839
# 38_Unknown              66.650839
# 39_Shell                67.991699
# 14_Sunoco               67.991699
# 10_Mobil                69.527035
# 29_BP                   69.527035
# dtype: object

# %% [markdown]
# - The distance among gas stations and schools:

# %%
D_Matrix_fuel_school=fuelBoston.geometry.apply\
(lambda station: schoolBoston.geometry.distance(station))

D_Matrix_fuel_school
# Out:
# newname               0_Boston Police Academy  1_Urban Science Academy  \
# newname
# 0_Unknown                         3517.172373              4538.314533
# 1_Shell                          12244.290100              9343.647624
# 2_Columbia Road Gulf              9473.181799             10605.020433
# 3_Shell                           6090.044288              2180.682657
# 4_Unknown                         3591.058820              2656.779444
# 5_Speedway                        3795.183476              2843.577257
# 6_Speedway                        5222.069546              1958.824895
# 7_JP Oil                          7693.440150              6373.595359
# 8_Emporium Gas                    5303.105183              4857.317730
# 9_Shell                          15157.800501             14938.190513
# 10_Mobil                         16358.216923             16223.796610
# 11_Unknown                       17665.843541             17806.224681
# 12_Gulf                           7061.719562             10542.249902
# 13_Unknown                        4080.652814              3552.318815
# 14_Sunoco                        10901.121494              9547.031834
# 15_Mobil                         16267.701995             15759.724979
# 16_Shell                         14440.714880             13538.623725
# 17_BP                              469.874927              5568.452607
# 18_Citgo                          9287.278497              7515.677654
# 19_Speedway                      11636.466247              8643.970638
# 20_Speedway                      15226.793161             13592.706757
# 21_Irving                        11870.225982              8655.112492
# 22_Stop & Shop                    3178.472883              4931.935145
# 23_Cumberland Farms              10846.887662              6864.922996
# 24_Mobil                         10890.973833              7440.036706
# 25_Sunoco                         4453.194738              8409.017121
# 26_Sunoco                         2741.032166              5734.608308
# 27_Sunoco                         5220.777784              8671.059439
# 28_Shell - Nouria                15020.456582             15239.672347
# 29_BP                            16300.299809             16189.100233
# 30_Speedway                       9515.762040             10619.449608
# 31_Speedway                      10861.777471             11404.312305
# 32_Sunoco                         9982.303122             10102.553945
# 33_Gulf                          10526.096257              9946.115422
# 34_Mobil                          1566.409581              6354.217393
# 35_Gulf                          12254.991966              8455.245405
# 36_Oak Square Sunoco             12053.366280              7594.663390
# 37_US Gas                         8727.556448             10090.586422
# 38_Unknown                       10061.196325             10186.215670
# 39_Shell                         10969.094155              9602.990813
# 40_Gibbs Gas Station              7443.863806              6142.119235
# 41_Unknown                        7498.405426             10904.079985
# 42_Citgo                          7740.401250             10470.159272
# 43_Unknown                        3511.767409              4529.754693
# 44_JP Gas                         7509.760031              6200.978894
# 45_Stan Hatoff's                  6625.150508              6263.984425
# 46_Unknown                        9535.740013              8157.211643
# 47_Southie Gas                   11532.102708             11797.575407
# 48_Stop & Shop Gas                9597.003325             10225.535929
# 49_Unknown                        8080.699543              6768.135967
# 50_Nouria                        12782.066700              9674.770637
# 51_Shell                         10633.861540              9994.396431
# 52_Speedway                       6941.368375             10399.912991
# 53_Roger's Services               1717.140522              6092.064028
# 54_Unknown                        6279.229318              1605.399483
#
# newname               2_Boston Middle School Academy  \
# newname
# 0_Unknown                                3668.709777
# 1_Shell                                  7157.251605
# 2_Columbia Road Gulf                     3203.648108
# 3_Shell                                  5758.089941
# 4_Unknown                                7324.527882
# 5_Speedway                               7867.642325
# 6_Speedway                               5667.363486
# 7_JP Oil                                 2909.009606
# 8_Emporium Gas                           2776.611052
# 9_Shell                                  8701.081274
# 10_Mobil                                 9912.239362
# 11_Unknown                              11267.870880
# 12_Gulf                                  3764.423343
# 13_Unknown                               4258.513802
# 14_Sunoco                                4916.263311
# 15_Mobil                                 9809.795464
# 16_Shell                                 8045.073267
# 17_BP                                    6507.360866
# 18_Citgo                                 4038.636839
# 19_Speedway                              6763.627624
# 20_Speedway                              9022.401992
# 21_Irving                                7151.432770
# 22_Stop & Shop                           3647.903527
# 23_Cumberland Farms                      7230.255654
# 24_Mobil                                 6679.146972
# 25_Sunoco                                3476.300224
# 26_Sunoco                                3731.681987
# 27_Sunoco                                2850.621131
# 28_Shell - Nouria                        8610.477925
# 29_BP                                    9856.124012
# 30_Speedway                              3234.481507
# 31_Speedway                              4443.451309
# 32_Sunoco                                3529.201636
# 33_Gulf                                  4210.407014
# 34_Mobil                                 8009.632168
# 35_Gulf                                  8033.198954
# 36_Oak Square Sunoco                     8650.558444
# 37_US Gas                                2556.080511
# 38_Unknown                               3607.646402
# 39_Shell                                 4981.065332
# 40_Gibbs Gas Station                     2829.710284
# 41_Unknown                               3955.871282
# 42_Citgo                                 3105.659602
# 43_Unknown                               3661.196080
# 44_JP Gas                                2860.890588
# 45_Stan Hatoff's                         1817.912100
# 46_Unknown                               3856.897135
# 47_Southie Gas                           5084.633059
# 48_Stop & Shop Gas                       3162.983571
# 49_Unknown                               3006.427833
# 50_Nouria                                7770.920368
# 51_Shell                                 4331.026866
# 52_Speedway                              3643.149061
# 53_Roger's Services                      8094.398370
# 54_Unknown                               6407.161770
#
# newname               3_Ralph Waldo Emerson School  \
# newname
# 0_Unknown                              6175.633927
# 1_Shell                                5852.503222
# 2_Columbia Road Gulf                   1383.419611
# 3_Shell                                7444.959838
# 4_Unknown                              9722.650156
# 5_Speedway                            10273.832679
# 6_Speedway                             7620.966318
# 7_JP Oil                               3405.277505
# 8_Emporium Gas                         4840.864788
# 9_Shell                                6035.637704
# 10_Mobil                               7259.516736
# 11_Unknown                             8660.220854
# 12_Gulf                                4915.236453
# 13_Unknown                             6547.761693
# 14_Sunoco                              3024.495784
# 15_Mobil                               7138.911343
# 16_Shell                               5431.368540
# 17_BP                                  9170.563797
# 18_Citgo                               3382.781979
# 19_Speedway                            5701.428919
# 20_Speedway                            6577.563595
# 21_Irving                              6149.593725
# 22_Stop & Shop                         6237.554989
# 23_Cumberland Farms                    6996.060967
# 24_Mobil                               6147.512759
# 25_Sunoco                              5786.773865
# 26_Sunoco                              6398.351227
# 27_Sunoco                              4981.881475
# 28_Shell - Nouria                      6002.151899
# 29_BP                                  7205.522731
# 30_Speedway                            1359.159815
# 31_Speedway                            1894.149549
# 32_Sunoco                               873.919071
# 33_Gulf                                1869.245772
# 34_Mobil                              10678.153618
# 35_Gulf                                7264.789243
# 36_Oak Square Sunoco                   8322.831686
# 37_US Gas                              1496.998048
# 38_Unknown                              949.118816
# 39_Shell                               3065.479020
# 40_Gibbs Gas Station                   3528.577838
# 41_Unknown                             4861.982254
# 42_Citgo                               3675.815639
# 43_Unknown                             6168.946268
# 44_JP Gas                              3509.017589
# 45_Stan Hatoff's                       3264.163426
# 46_Unknown                             2745.645425
# 47_Southie Gas                         2446.471344
# 48_Stop & Shop Gas                      697.924304
# 49_Unknown                             3138.662628
# 50_Nouria                              6448.401569
# 51_Shell                               1999.731457
# 52_Speedway                            4853.510105
# 53_Roger's Services                   10757.077083
# 54_Unknown                             8097.652678
#
# newname               4_John Paul II Polish School  \
# newname
# 0_Unknown                              7363.805994
# 1_Shell                                6571.745828
# 2_Columbia Road Gulf                    820.705094
# 3_Shell                                8781.563134
# 4_Unknown                             10966.471948
# 5_Speedway                            11515.960465
# 6_Speedway                             8942.451556
# 7_JP Oil                               4728.536028
# 8_Emporium Gas                         6129.893860
# 9_Shell                                5102.936681
# 10_Mobil                               6253.604698
# 11_Unknown                             7547.343066
# 12_Gulf                                4985.405753
# 13_Unknown                             7810.830433
# 14_Sunoco                              3633.886009
# 15_Mobil                               6281.756881
# 16_Shell                               4900.826755
# 17_BP                                 10207.178933
# 18_Citgo                               4520.602291
# 19_Speedway                            6543.137544
# 20_Speedway                            6329.975072
# 21_Irving                              6997.135648
# 22_Stop & Shop                         7377.113881
# 23_Cumberland Farms                    8084.233635
# 24_Mobil                               7171.189445
# 25_Sunoco                              6407.541087
# 26_Sunoco                              7433.274499
# 27_Sunoco                              5544.913061
# 28_Shell - Nouria                      4896.753743
# 29_BP                                  6192.617515
# 30_Speedway                             746.108903
# 31_Speedway                             756.912965
# 32_Sunoco                              1143.303517
# 33_Gulf                                2299.456556
# 34_Mobil                              11687.207035
# 35_Gulf                                8167.702765
# 36_Oak Square Sunoco                   9353.465224
# 37_US Gas                              1529.699570
# 38_Unknown                             1124.605344
# 39_Shell                               3647.419520
# 40_Gibbs Gas Station                   4860.210314
# 41_Unknown                             4814.341292
# 42_Citgo                               3650.422547
# 43_Unknown                             7356.695153
# 44_JP Gas                              4838.670345
# 45_Stan Hatoff's                       4582.905439
# 46_Unknown                             3804.181282
# 47_Southie Gas                         1501.029845
# 48_Stop & Shop Gas                      609.914754
# 49_Unknown                             4439.073985
# 50_Nouria                              7131.045038
# 51_Shell                               2402.117492
# 52_Speedway                            4956.925220
# 53_Roger's Services                   11791.775792
# 54_Unknown                             9434.874568
#
# newname               5_Academy Of the Pacific Rim Charter Public School  \
# newname
# 0_Unknown                                                   3955.280914
# 1_Shell                                                    12526.745937
# 2_Columbia Road Gulf                                       10411.205910
# 3_Shell                                                     5845.185924
# 4_Unknown                                                   2720.954364
# 5_Speedway                                                  2784.007788
# 6_Speedway                                                  4947.709018
# 7_JP Oil                                                    8131.470068
# 8_Emporium Gas                                              5712.458287
# 9_Shell                                                    15977.085163
# 10_Mobil                                                   17202.552228
# 11_Unknown                                                 18562.201102
# 12_Gulf                                                     8256.768278
# 13_Unknown                                                  4212.735709
# 14_Sunoco                                                  11454.883135
# 15_Mobil                                                   17052.095638
# 29_BP                                        15136.054949
# 30_Speedway                                   9359.105692
# 31_Speedway                                  10211.055035
# 32_Sunoco                                     8938.241302
# 33_Gulf                                       8876.044838
# 34_Mobil                                      5720.981395
# 35_Gulf                                       8085.027921
# 36_Oak Square Sunoco                          7448.975185
# 37_US Gas                                     8802.733473
# 38_Unknown                                    9022.004951
# 39_Shell                                      8659.766844
# 40_Gibbs Gas Station                          5054.000282
# 41_Unknown                                    9555.357482
# 42_Citgo                                      9123.995803
# 43_Unknown                                    3196.533158
# 44_JP Gas                                     5117.724588
# 45_Stan Hatoff's                              5040.911815
# 46_Unknown                                    7176.519780
# 47_Southie Gas                               10643.385878
# 48_Stop & Shop Gas                            9004.705282
# 49_Unknown                                    5715.941687
# 50_Nouria                                     9122.408513
# 51_Shell                                      8934.819198
# 52_Speedway                                   9052.794529
# 53_Roger's Services                           5506.237536
# 54_Unknown                                    1178.925661
#
# newname               267_Frank W Thompson Middle School  \
# newname
# 0_Unknown                                    3107.703357
# 1_Shell                                      9298.057232
# 2_Columbia Road Gulf                         4752.045981
# 3_Shell                                      6237.546105
# 4_Unknown                                    6557.039305
# 5_Speedway                                   7049.037738
# 6_Speedway                                   5821.401338
# 7_JP Oil                                     4782.993855
# 8_Emporium Gas                               3435.568293
# 9_Shell                                     10568.544008
# 10_Mobil                                    11717.145264
# 11_Unknown                                  12946.646699
# 12_Gulf                                      2804.160045
# 13_Unknown                                   4092.824609
# 14_Sunoco                                    7141.617672
# 15_Mobil                                    11732.384264
# 16_Shell                                    10119.384290
# 17_BP                                        4857.998144
# 18_Citgo                                     6143.338332
# 19_Speedway                                  8852.131194
# 20_Speedway                                 11197.655911
# 21_Irving                                    9212.406327
# 22_Stop & Shop                               2785.020201
# 23_Cumberland Farms                          8997.074516
# 24_Mobil                                     8596.964075
# 25_Sunoco                                    1212.295980
# 26_Sunoco                                    2299.156110
# 27_Sunoco                                     944.424959
# 28_Shell - Nouria                           10325.826598
# 29_BP                                       11654.774739
# 30_Speedway                                  4799.092134
# 31_Speedway                                  6223.191361
# 32_Sunoco                                    5561.304523
# 33_Gulf                                      6382.904414
# 34_Mobil                                     6241.745613
# 35_Gulf                                      9992.322071
# 36_Oak Square Sunoco                        10404.394062
# 37_US Gas                                    3990.142907
# 38_Unknown                                   5634.437689
# 39_Shell                                     7206.268377
# 40_Gibbs Gas Station                         4626.627231
# 41_Unknown                                   3192.074497
# 42_Citgo                                     3055.652203
# 43_Unknown                                   3099.577923
# 44_JP Gas                                    4673.473838
# 45_Stan Hatoff's                             3514.503575
# 46_Unknown                                   6052.049378
# 47_Southie Gas                               6940.462037
# 48_Stop & Shop Gas                           5016.477254
# 49_Unknown                                   4999.300186
# 50_Nouria                                    9905.392454
# 51_Shell                                     6507.581191
# 52_Speedway                                  2662.757289
# 53_Roger's Services                          6395.846728
# 54_Unknown                                   6808.751484
#
# newname               268_Josiah Quincy Elementary School  \
# newname
# 0_Unknown                                     8744.745535
# 1_Shell                                       5126.352377
# 2_Columbia Road Gulf                          3060.289866
# 3_Shell                                       9379.137516
# 37_US Gas                                3670.467286
# 38_Unknown                               1778.773488
# 39_Shell                                 2538.250128
# 40_Gibbs Gas Station                     5441.221417
# 41_Unknown                               6993.020811
# 42_Citgo                                 5832.840476
# 43_Unknown                               8757.745976
# 44_JP Gas                                5398.247759
# 45_Stan Hatoff's                         5616.232681
# 46_Unknown                               3562.587620
# 47_Southie Gas                            880.619851
# 48_Stop & Shop Gas                       2407.364198
# 49_Unknown                               4830.782030
# 50_Nouria                                5704.685079
# 51_Shell                                 1634.019972
# 52_Speedway                              7138.546230
# 53_Roger's Services                     13455.151813
# 54_Unknown                              10054.408710
#
# newname               270_Italian Home for Children School
# newname
# 0_Unknown                                      2519.578877
# 1_Shell                                        6028.525154
# 2_Columbia Road Gulf                           6018.628205
# 3_Shell                                        2315.987018
# 4_Unknown                                      5097.389773
# 5_Speedway                                     5635.160194
# 6_Speedway                                     2552.817236
# 7_JP Oil                                       1899.450800
# 8_Emporium Gas                                  932.157757
# 9_Shell                                       10446.347546
# 10_Mobil                                      11729.335475
# 11_Unknown                                    13271.598347
# 12_Gulf                                        6861.453393
# 13_Unknown                                     2086.652789
# 14_Sunoco                                      5281.489388
# 15_Mobil                                      11355.778273
# 16_Shell                                       9223.983348
# 17_BP                                          5811.015090
# 18_Citgo                                       3335.629921
# 19_Speedway                                    5397.904103
# 20_Speedway                                    9566.877834
# 21_Irving                                      5616.827699
# 22_Stop & Shop                                 2949.322087
# 23_Cumberland Farms                            4741.600117
# 24_Mobil                                       4652.579764
# 25_Sunoco                                      5535.075763
# 26_Sunoco                                      3769.668170
# 27_Sunoco                                      5368.590957
# 28_Shell - Nouria                             10667.357805
# 29_BP                                         11689.041224
# 30_Speedway                                    6028.603654
# 31_Speedway                                    6770.896632
# 32_Sunoco                                      5479.332736
# 33_Gulf                                        5432.357621
# 34_Mobil                                       7277.507903
# 35_Gulf                                        6040.098125
# 36_Oak Square Sunoco                           6075.423821
# 37_US Gas                                      5567.616082
# 38_Unknown                                     5563.106622
# 39_Shell                                       5344.493879
# 40_Gibbs Gas Station                           1637.555113
# 41_Unknown                                     7128.010901
# 42_Citgo                                       6395.273943
# 43_Unknown                                     2513.769358
# 44_JP Gas                                      1705.921563
# 45_Stan Hatoff's                               1658.227631
# 46_Unknown                                     3838.485615
# 47_Southie Gas                                 7181.861244
# 48_Stop & Shop Gas                             5596.302919
# 49_Unknown                                     2327.448123
# 50_Nouria                                      6544.448882
# 51_Shell                                       5497.921282
# 52_Speedway                                    6726.118214
# 53_Roger's Services                            7213.159399
# 54_Unknown                                     2972.698228
#
# [55 rows x 271 columns]

# %% [markdown]
# # Decision 1: Find the stations that should go away
#
#
#
# Now, we could compute the minimal distance from a gas station to a school, and sort the stations by that value:

# %%
D_Matrix_fuel_school.min(axis=1).sort_values().head(10)
# Out:
# newname
# 29_BP                    16.344538
# 37_US Gas                16.817808
# 9_Shell                  47.383312
# 7_JP Oil                 82.297014
# 10_Mobil                 91.365677
# 2_Columbia Road Gulf     96.766745
# 30_Speedway              98.044988
# 42_Citgo                100.187359
# 51_Shell                171.630269
# 43_Unknown              176.522893
# dtype: float64

# %% [markdown]
# By the previous exploration, we may decide that no station should at 100 or less from a school:

# %%
mindDist=200

# %% [markdown]
# # Decision 2: Secure perimeter of every school
#
# Let's create the safe area around the school. This requires **buffer**:

# %%
schoolBoston_buffered=schoolBoston.buffer(mindDist)
schoolBoston_buffered
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# newname
# 0_Boston Police Academy                 POLYGON ((231787.542 888708.322, 231786.579 88...
# 1_Urban Science Academy                 POLYGON ((227076.32 892442.908, 227075.357 892...
# 2_Boston Middle School Academy          POLYGON ((234381.887 894623.399, 234380.924 89...
# 3_Ralph Waldo Emerson School            POLYGON ((235409.779 897088.628, 235408.816 89...
# 4_John Paul II Polish School            POLYGON ((236651.673 897587.454, 236650.71 897...
#                                                               ...
# 266_Robert Gould Shaw Middle School     POLYGON ((228308.356 892736.322, 228320.718 89...
# 267_Frank W Thompson Middle School      POLYGON ((234435.987 892590.421, 234472.611 89...
# 268_Josiah Quincy Elementary School     POLYGON ((235913.51 900053.813, 235918.982 900...
# 269_Josiah Quincy Upper School          POLYGON ((235950.61 899983.426, 235994.045 899...
# 270_Italian Home for Children School    POLYGON ((230501.236 894635.169, 230485.833 89...
# Length: 271, dtype: geometry

# %%
#remember we have
type(schoolBoston_buffered)
# Out:
# geopandas.geoseries.GeoSeries

# %% [markdown]
# Turning GS into GDF:

# %%
secured_schoolBoston=gpd.GeoDataFrame(geometry=schoolBoston_buffered)
secured_schoolBoston
# Out:
#                                                                                geometry
# newname
# 0_Boston Police Academy               POLYGON ((231787.542 888708.322, 231786.579 88...
# 1_Urban Science Academy               POLYGON ((227076.32 892442.908, 227075.357 892...
# 2_Boston Middle School Academy        POLYGON ((234381.887 894623.399, 234380.924 89...
# 3_Ralph Waldo Emerson School          POLYGON ((235409.779 897088.628, 235408.816 89...
# 4_John Paul II Polish School          POLYGON ((236651.673 897587.454, 236650.71 897...
# ...                                                                                 ...
# 266_Robert Gould Shaw Middle School   POLYGON ((228308.356 892736.322, 228320.718 89...
# 267_Frank W Thompson Middle School    POLYGON ((234435.987 892590.421, 234472.611 89...
# 268_Josiah Quincy Elementary School   POLYGON ((235913.51 900053.813, 235918.982 900...
# 269_Josiah Quincy Upper School        POLYGON ((235950.61 899983.426, 235994.045 899...
# 270_Italian Home for Children School  POLYGON ((230501.236 894635.169, 230485.833 89...
#
# [271 rows x 1 columns]

# %% [markdown]
# Buffers created polygons:

# %%
secured_schoolBoston.geometry.geom_type.value_counts()
# Out:
# Polygon    271
# Name: count, dtype: int64

# %% [markdown]
# # Decision 3: Standardized Gas stations geometries

# %% [markdown]
# Not all gas stations are points:

# %%
fuelBoston.geometry.geom_type.value_counts()
# Out:
# Point      28
# Polygon    27
# Name: count, dtype: int64

# %% [markdown]
# The point is a simple representation. Then let's make a buffer of 10 meters for every station to make sure the station is selected even if we just had one of its points.

# %%
fuelBoston_allPoly=fuelBoston.copy()
fuelBoston_allPoly['geometry'] = [
    station.buffer(10) if station.geom_type == 'Point' else station
    for station in fuelBoston.geometry
]

# %%
# rechecking
fuelBoston_allPoly.geometry.geom_type.value_counts()
# Out:
# Polygon    55
# Name: count, dtype: int64

# %% [markdown]
# # Decision 4: Overlay or SJoin to determine gas stations in trouble

# %%
fuelBoston_allPoly.sjoin(secured_schoolBoston,how='inner',predicate='intersects')
# Out:
#                      element  \
# newname_left
# 0_Unknown               node
# 2_Columbia Road Gulf    node
# 4_Unknown               node
# 7_JP Oil                node
# 8_Emporium Gas          node
# 9_Shell                 node
# 9_Shell                 node
# 10_Mobil                node
# 10_Mobil                node
# 18_Citgo                node
# 23_Cumberland Farms     node
# 29_BP                    way
# 29_BP                    way
# 30_Speedway              way
# 37_US Gas                way
# 42_Citgo                 way
# 43_Unknown               way
# 46_Unknown               way
# 46_Unknown               way
# 51_Shell                 way
#
#                                                                geometry  \
# newname_left
# 0_Unknown             POLYGON ((231419.205 892220.97, 231419.157 892...
# 2_Columbia Road Gulf  POLYGON ((236566.832 896773.514, 236566.784 89...
# 4_Unknown             POLYGON ((228339.637 890218.87, 228339.589 890...
# 7_JP Oil              POLYGON ((231885.609 896396.367, 231885.561 89...
# 8_Emporium Gas        POLYGON ((231483.832 894010.207, 231483.783 89...
# 9_Shell               POLYGON ((237964.475 902464.087, 237964.427 90...
# 9_Shell               POLYGON ((237964.475 902464.087, 237964.427 90...
# 10_Mobil              POLYGON ((238900.219 903346.019, 238900.171 90...
# 10_Mobil              POLYGON ((238900.219 903346.019, 238900.171 90...
# 18_Citgo              POLYGON ((231958.901 897988.567, 231958.853 89...
# 23_Cumberland Farms   POLYGON ((228522.125 899110.09, 228522.077 899...
# 29_BP                 POLYGON ((238911.72 903270.471, 238908.242 903...
# 29_BP                 POLYGON ((238911.72 903270.471, 238908.242 903...
# 30_Speedway           POLYGON ((236557.367 896829.256, 236547.608 89...
# 37_US Gas             POLYGON ((236306.663 896049.993, 236296.682 89...
# 42_Citgo              POLYGON ((237234.382 894002.376, 237227.605 89...
# 43_Unknown            POLYGON ((231416.362 892215.914, 231400.476 89...
# 46_Unknown            POLYGON ((232690.085 898180.108, 232662.26 898...
# 46_Unknown            POLYGON ((232690.085 898180.108, 232662.26 898...
# 51_Shell              POLYGON ((234466.438 898945.068, 234456.92 898...
#
#                                                  newname_right
# newname_left
# 0_Unknown                              143_Sacred Heart School
# 2_Columbia Road Gulf    138_Pope John Paul II Catholic Academy
# 4_Unknown                                  32_Beethoven School
# 7_JP Oil                                 194_Curley K-8 School
# 8_Emporium Gas          175_Boston Teachers Union Pilot School
# 9_Shell                  239_Dante Alighieri Montessori School
# 9_Shell                       240_East Boston Central Catholic
# 10_Mobil                 213_Excel Academy Charter High School
# 10_Mobil              214_Patrick J. Kennedy Elementary School
# 18_Citgo                                           42_Manville
# 23_Cumberland Farms                  207_Bais Yaakov of Boston
# 29_BP                    213_Excel Academy Charter High School
# 29_BP                 214_Patrick J. Kennedy Elementary School
# 30_Speedway             138_Pope John Paul II Catholic Academy
# 37_US Gas                 176_Edward Everett Elementary School
# 42_Citgo                          235_Richard J. Murphy School
# 43_Unknown                             143_Sacred Heart School
# 46_Unknown                          226_Mission Grammar School
# 46_Unknown                  162_David Farragut School (closed)
# 51_Shell                      14_Carter Developmental Day Care

# %%
gas_relocate=fuelBoston_allPoly.sjoin(secured_schoolBoston,how='inner',predicate='intersects')

# %% [markdown]
# It is possible the index may have duplicates:

# %%
is_duplicate = gas_relocate.index.duplicated(keep=False)

gas_relocate[is_duplicate]
# Out:
#              element                                           geometry  \
# newname_left
# 9_Shell         node  POLYGON ((237964.475 902464.087, 237964.427 90...
# 9_Shell         node  POLYGON ((237964.475 902464.087, 237964.427 90...
# 10_Mobil        node  POLYGON ((238900.219 903346.019, 238900.171 90...
# 10_Mobil        node  POLYGON ((238900.219 903346.019, 238900.171 90...
# 29_BP            way  POLYGON ((238911.72 903270.471, 238908.242 903...
# 29_BP            way  POLYGON ((238911.72 903270.471, 238908.242 903...
# 46_Unknown       way  POLYGON ((232690.085 898180.108, 232662.26 898...
# 46_Unknown       way  POLYGON ((232690.085 898180.108, 232662.26 898...
#
#                                          newname_right
# newname_left
# 9_Shell          239_Dante Alighieri Montessori School
# 9_Shell               240_East Boston Central Catholic
# 10_Mobil         213_Excel Academy Charter High School
# 10_Mobil      214_Patrick J. Kennedy Elementary School
# 29_BP            213_Excel Academy Charter High School
# 29_BP         214_Patrick J. Kennedy Elementary School
# 46_Unknown                  226_Mission Grammar School
# 46_Unknown          162_David Farragut School (closed)

# %% [markdown]
# Remember our names are on the row index, then:

# %%
# put the index as a column: reset_index(drop=False)
# drop duplicates in that column:drop_duplicates(subset='newname_left')
# column bask to index : set_index('newname_left')

gas_relocate.reset_index(drop=False).\
drop_duplicates(subset='newname_left').\
set_index('newname_left')
# Out:
#                      element  \
# newname_left
# 0_Unknown               node
# 2_Columbia Road Gulf    node
# 4_Unknown               node
# 7_JP Oil                node
# 8_Emporium Gas          node
# 9_Shell                 node
# 10_Mobil                node
# 18_Citgo                node
# 23_Cumberland Farms     node
# 29_BP                    way
# 30_Speedway              way
# 37_US Gas                way
# 42_Citgo                 way
# 43_Unknown               way
# 46_Unknown               way
# 51_Shell                 way
#
#                                                                geometry  \
# newname_left
# 0_Unknown             POLYGON ((231419.205 892220.97, 231419.157 892...
# 2_Columbia Road Gulf  POLYGON ((236566.832 896773.514, 236566.784 89...
# 4_Unknown             POLYGON ((228339.637 890218.87, 228339.589 890...
# 7_JP Oil              POLYGON ((231885.609 896396.367, 231885.561 89...
# 8_Emporium Gas        POLYGON ((231483.832 894010.207, 231483.783 89...
# 9_Shell               POLYGON ((237964.475 902464.087, 237964.427 90...
# 10_Mobil              POLYGON ((238900.219 903346.019, 238900.171 90...
# 18_Citgo              POLYGON ((231958.901 897988.567, 231958.853 89...
# 23_Cumberland Farms   POLYGON ((228522.125 899110.09, 228522.077 899...
# 29_BP                 POLYGON ((238911.72 903270.471, 238908.242 903...
# 30_Speedway           POLYGON ((236557.367 896829.256, 236547.608 89...
# 37_US Gas             POLYGON ((236306.663 896049.993, 236296.682 89...
# 42_Citgo              POLYGON ((237234.382 894002.376, 237227.605 89...
# 43_Unknown            POLYGON ((231416.362 892215.914, 231400.476 89...
# 46_Unknown            POLYGON ((232690.085 898180.108, 232662.26 898...
# 51_Shell              POLYGON ((234466.438 898945.068, 234456.92 898...
#
#                                                newname_right
# newname_left
# 0_Unknown                            143_Sacred Heart School
# 2_Columbia Road Gulf  138_Pope John Paul II Catholic Academy
# 4_Unknown                                32_Beethoven School
# 7_JP Oil                               194_Curley K-8 School
# 8_Emporium Gas        175_Boston Teachers Union Pilot School
# 9_Shell                239_Dante Alighieri Montessori School
# 10_Mobil               213_Excel Academy Charter High School
# 18_Citgo                                         42_Manville
# 23_Cumberland Farms                207_Bais Yaakov of Boston
# 29_BP                  213_Excel Academy Charter High School
# 30_Speedway           138_Pope John Paul II Catholic Academy
# 37_US Gas               176_Edward Everett Elementary School
# 42_Citgo                        235_Richard J. Murphy School
# 43_Unknown                           143_Sacred Heart School
# 46_Unknown                        226_Mission Grammar School
# 51_Shell                    14_Carter Developmental Day Care

# %%
#making the actual change
gas_relocate= gas_relocate.reset_index(drop=False).drop_duplicates(subset='newname_left').\
              set_index('newname_left')

# %% [markdown]
# Let's see both schools and those stations to relocate:

# %%
base=secured_schoolBoston.sjoin(gas_relocate,how='inner',predicate='intersects').explore(color='yellow', tiles='cartodbpositron')
gas_relocate.explore(m=base,color='red')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f81db40b9fda53d6fab690196afce5d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f81db40b9fda53d6fab690196afce5d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f81db40b9fda53d6fab690196afce5d = L.map(
#                 &quot;map_5f81db40b9fda53d6fab690196afce5d&quot;,
#                 {
#                     center: [42.32131217736193, -71.09111173711108],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5f81db40b9fda53d6fab690196afce5d);
#
#
#
#
#
#             var tile_layer_8a12252b3b63e395f0f5c0c8ab387f58 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8a12252b3b63e395f0f5c0c8ab387f58.addTo(map_5f81db40b9fda53d6fab690196afce5d);
#
#
#             map_5f81db40b9fda53d6fab690196afce5d.fitBounds(
#                 [[42.26172542195667, -71.15825377659922], [42.3808989327672, -71.02396969762292]],
#                 {}
#             );
#
#
#         function geo_json_ba2847607ed1483d80e8d8f7c2efbef3_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;yellow&quot;, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_ba2847607ed1483d80e8d8f7c2efbef3_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_ba2847607ed1483d80e8d8f7c2efbef3_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 2,
# };
#
#             let style = geo_json_ba2847607ed1483d80e8d8f7c2efbef3_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_ba2847607ed1483d80e8d8f7c2efbef3_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_ba2847607ed1483d80e8d8f7c2efbef3.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_ba2847607ed1483d80e8d8f7c2efbef3_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_ba2847607ed1483d80e8d8f7c2efbef3 = L.geoJson(null, {
#                 onEachFeature: geo_json_ba2847607ed1483d80e8d8f7c2efbef3_onEachFeature,
#
#                 style: geo_json_ba2847607ed1483d80e8d8f7c2efbef3_styler,
#                 pointToLayer: geo_json_ba2847607ed1

# %% [markdown]
# # Decision 5: Find suitable places for the stations in trouble
#
#
# We can not put the gas stations anywhere. They need to be situated on driveable routes, not inside a house or building.
#
#
# - Find suitable locations along routes
#
# Let's get the streets from Boston with the help of OSM:

# %%
# Define the place
place = "Boston, Massachusetts, USA"

# Download the street network graph for Boston
G = ox.graph_from_place(place, network_type="drive")

# Convert the graph edges (streets) to a GeoDataFrame
streets = ox.graph_to_gdfs(G, nodes=False, edges=True)

streets.shape
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:451: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/predicates.py:878: RuntimeWarning: invalid value encountered in intersects
#   return lib.intersects(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:451: RuntimeWarning: invalid value encountered in union
#   return lib.union(a, b, **kwargs)
# (26073, 16)

# %% [markdown]
# You see we got a huge set of routes:

# %%
streets.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# MultiIndex: 26073 entries, (np.int64(30730954), np.int64(61441677), np.int64(0)) to (np.int64(13291306961), np.int64(61502104), np.int64(0))
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   osmid     26073 non-null  object
#  1   highway   26073 non-null  object
#  2   lanes     24338 non-null  object
#  3   maxspeed  24271 non-null  object
#  4   name      25310 non-null  object
#  5   oneway    26073 non-null  bool
#  6   reversed  26073 non-null  object
#  7   length    26073 non-null  float64
#  8   geometry  26073 non-null  geometry
#  9   width     23377 non-null  object
#  10  ref       915 non-null    object
#  11  access    255 non-null    object
#  12  bridge    386 non-null    object
#  13  tunnel    124 non-null    object
#  14  junction  104 non-null    object
#  15  service   1 non-null      object
# dtypes: bool(1), float64(1), geometry(1), object(13)
# memory usage: 3.8+ MB

# %%
streets.highway.value_counts().index
# Out:
# Index([                    'residential',                       'secondary',
#                                'primary',                        'tertiary',
#                                  'trunk',                    'unclassified',
#                          'motorway_link',                    'primary_link',
#                             'trunk_link',                        'motorway',
#                         'secondary_link',                          'busway',
#                          'living_street',                   'tertiary_link',
#          ['residential', 'unclassified'], ['living_street', 'unclassified'],
#         ['residential', 'living_street'],       ['primary', 'primary_link'],
#                ['secondary', 'tertiary'],             ['trunk', 'motorway'],
#                          'emergency_bay',      ['primary', 'motorway_link']],
#       dtype='object', name='highway')

# %%
GAS_STATION_ROAD_TYPES = [
    'motorway',      # High-speed limited access roads
    'primary',       # Major national roads
    'trunk',         # Important regional roads
    'motorway_link', # Motorway entrance/exit ramps
    'primary_link',  # Primary road connectors
    'trunk_link',     # Trunk road connectors
    ['motorway', 'trunk'],
    ['primary', 'motorway_link'],
    ['primary', 'primary_link']
]

suitable_roads = streets[streets.highway.isin(GAS_STATION_ROAD_TYPES)]

suitable_roads.shape
# Out:
# (3959, 16)

# %% [markdown]
# Let's reproject:

# %%
suitable_roads = suitable_roads.to_crs(boston.crs)

# %% [markdown]
# The possible locations should be:
# - Far enough from schools. They should be far from the GDF **secured_schoolBoston** (already buffered with a secure radius) .
# - Far from other Gast stations. From **fuelBoston_allPoly** we could add a secured distance. This GDF was was buffered, but just to include the building, so we need to re buffer.
#
# Then, we need to create a buffer around the stations:

# %%
competitionDistance=100 # a safe value from above 'D_Matrix_fuel_fuel'
fuelBoston_allPoly_buffered=fuelBoston_allPoly.buffer(competitionDistance)
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/constructive.py:246: RuntimeWarning: invalid value encountered in buffer
#   return lib.buffer(

# %%
type(fuelBoston_allPoly_buffered)
# Out:
# geopandas.geoseries.GeoSeries

# %%
secured_fuelBoston_allPoly=gpd.GeoDataFrame(geometry=fuelBoston_allPoly_buffered)

# %% [markdown]
# Let's combine the secured areas:

# %%
secured_areas_dissolved=secured_fuelBoston_allPoly.overlay(secured_schoolBoston,how='union',keep_geom_type=False).dissolve()
secured_areas=gpd.GeoDataFrame(geometry=secured_areas_dissolved.geometry)
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:553: RuntimeWarning: invalid value encountered in unary_union
#   return lib.unary_union(collections, **kwargs)

# %% [markdown]
# - Filter the roads. We can NOT choose a location that intersects with the secured areas:

# %%
suitable_roads.overlay(secured_areas,keep_geom_type=False, how='difference').plot()
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# <Axes: >

# %%
good_routes_forGas_dissolved=suitable_roads.overlay(secured_areas,keep_geom_type=False, how='difference').dissolve()
good_routes_forGas=gpd.GeoDataFrame(geometry=good_routes_forGas_dissolved.geometry)
good_routes_forGas
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:553: RuntimeWarning: invalid value encountered in unary_union
#   return lib.unary_union(collections, **kwargs)
#                                             geometry
# 0  MULTILINESTRING ((233360.211 896561.197, 23336...

# %%
good_routes_forGas.plot()
# Out:
# <Axes: >

# %% [markdown]
# We may choose a location from those places:

# %%
# newCOMPETITORS=safe_fuelCompetitors_gdf.copy()
potential_Locations=good_routes_forGas.copy()
newPOLYGONS=[]
pointsComputed=1
attempts=1
while pointsComputed<=len(gas_relocate):
  candidatePoint=potential_Locations.sample_points(1)
  candidateStation=gpd.GeoDataFrame(geometry=candidatePoint.buffer(100))
  if candidateStation.overlay(secured_areas,how='intersection',keep_geom_type=False).empty:
    newPOLYGONS.append(candidateStation)
    pointsComputed+=1
    potential_Locations=potential_Locations.overlay(candidateStation, how='difference', keep_geom_type=False)
  if attempts>len(gas_relocate)*10:
    break
  attempts+=1

# some info
attempts,len(newPOLYGONS)
# Out:
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:168: RuntimeWarning: invalid value encountered in intersection
#   return lib.intersection(a, b, **kwargs)
# /opt/anaconda3/envs/DACSS_690D/lib/python3.11/site-packages/shapely/set_operations.py:100: RuntimeWarning: invalid value encountered in difference
#   return lib.difference(a, b, **kwargs)
# (32, 16)

# %%
newPOLYGONS
# Out:
# [                                            geometry
#  0  POLYGON ((236223.895 897961.156, 236223.413 89...,
#                                              geometry
#  0  POLYGON ((236810.634 900531.622, 236810.153 90...,
#                                              geometry
#  0  POLYGON ((238375.547 898858.472, 238375.066 89...,
#                                              geometry
#  0  POLYGON ((236475.145 900023.769, 236474.663 90...,
#                                              geometry
#  0  POLYGON ((229164.451 891100.614, 229163.97 891...,
#                                              geometry
#  0  POLYGON ((234679.522 899766.092, 234679.041 89...,
#                                              geometry
#  0  POLYGON ((228969.135 901148.662, 228968.654 90...,
#                                              geometry
#  0  POLYGON ((237714.697 893554.29, 237714.215 893...,
#                                              geometry
#  0  POLYGON ((236493.506 892477.683, 236493.024 89...,
#                                              geometry
#  0  POLYGON ((229107.064 901201.04, 229106.582 901...,
#                                              geometry
#  0  POLYGON ((227144.87 891215.745, 227144.388 891...,
#                                              geometry
#  0  POLYGON ((233620.998 895774.815, 233620.516 89...,
#                                              geometry
#  0  POLYGON ((237530.122 899832.218, 237529.64 899...,
#                                              geometry
#  0  POLYGON ((238663.512 899998.745, 238663.031 89...,
#                                              geometry
#  0  POLYGON ((235628.44 902566.391, 235627.959 902...,
#                                              geometry
#  0  POLYGON ((228997.517 890905.227, 228997.035 89...]

# %%
import pandas as pd
pd.concat(newPOLYGONS)
# Out:
#                                             geometry
# 0  POLYGON ((236223.895 897961.156, 236223.413 89...
# 0  POLYGON ((236810.634 900531.622, 236810.153 90...
# 0  POLYGON ((238375.547 898858.472, 238375.066 89...
# 0  POLYGON ((236475.145 900023.769, 236474.663 90...
# 0  POLYGON ((229164.451 891100.614, 229163.97 891...
# 0  POLYGON ((234679.522 899766.092, 234679.041 89...
# 0  POLYGON ((228969.135 901148.662, 228968.654 90...
# 0  POLYGON ((237714.697 893554.29, 237714.215 893...
# 0  POLYGON ((236493.506 892477.683, 236493.024 89...
# 0  POLYGON ((229107.064 901201.04, 229106.582 901...
# 0  POLYGON ((227144.87 891215.745, 227144.388 891...
# 0  POLYGON ((233620.998 895774.815, 233620.516 89...
# 0  POLYGON ((237530.122 899832.218, 237529.64 899...
# 0  POLYGON ((238663.512 899998.745, 238663.031 89...
# 0  POLYGON ((235628.44 902566.391, 235627.959 902...
# 0  POLYGON ((228997.517 890905.227, 228997.035 89...

# %%
GoodLocationsGas_buffered_gdf=pd.concat(newPOLYGONS)
GoodLocationsGas_gdf=gpd.GeoDataFrame(geometry=GoodLocationsGas_buffered_gdf.centroid)

# %%
# original suitable roads
base = suitable_roads.plot(color='yellow', figsize=(10, 10),zorder=1)

# non-overlapping buffers
GoodLocationsGas_buffered_gdf.plot(ax=base, edgecolor='red', marker="+", facecolor='none',zorder=2)

# center points of the buffers
GoodLocationsGas_gdf.plot(ax=base, color='red', marker="+", markersize=50,zorder=3)

# all stations
fuelBoston.plot(ax=base,color='k',zorder=4)
schoolBoston.plot(ax=base,color='green',zorder=5)

# stations to relocate
fuelBoston.clip(gas_relocate).plot(ax=base,color='magenta',zorder=5)
# Out:
# <Axes: >

# %% [markdown]
# ## Reverse geocoding
#
# Just get some addresses:

# %%
from geopy.geocoders import Nominatim
import time

# Initialize geocoder
geolocator = Nominatim(user_agent="boston_gas_stations")

def get_address(point):
  # Now coordinates are in degrees (lon, lat)
  lon = point.x
  lat = point.y
  location = geolocator.reverse((lat, lon), exactly_one=True, timeout=10)
  time.sleep(1)  # Rate limiting

  if location:
    return location.address
  else:
    return None # not found

# %%
# Get addresses
GoodLocationsGas_4326 = GoodLocationsGas_gdf.to_crs('EPSG:4326')
GoodLocationsGas_gdf['address'] = GoodLocationsGas_4326.geometry.apply(get_address)

# %%
GoodLocationsGas_gdf
# Out:
#                         geometry  \
# 0  POINT (236123.895 897961.156)
# 0  POINT (236710.634 900531.622)
# 0  POINT (238275.547 898858.472)
# 0  POINT (236375.145 900023.769)
# 0  POINT (229064.451 891100.614)
# 0  POINT (234579.522 899766.092)
# 0  POINT (228869.135 901148.662)
# 0   POINT (237614.697 893554.29)
# 0  POINT (236393.506 892477.683)
# 0   POINT (229007.064 901201.04)
# 0   POINT (227044.87 891215.745)
# 0  POINT (233520.998 895774.815)
# 0  POINT (237430.122 899832.218)
# 0  POINT (238563.512 899998.745)
# 0   POINT (235528.44 902566.391)
# 0  POINT (228897.517 890905.227)
#
#                                              address
# 0  Frontage Road Northbound, South Boston, Boston...
# 0  234,236, Congress Street, Financial District, ...
# 0  Edison Power Station, 776, Summer Street, City...
# 0  Kneeland Street, Leather District, Downtown Bo...
# 0  4903, Washington Street, West Roxbury, Boston,...
# 0  Prudential Center, Massachusetts Turnpike, Bac...
# 0  1550, Soldiers Field Road, North Brighton, Bri...
# 0  Southeast Expressway, Neponset, Dorchester, Bo...
# 0  856, Adams Street, Cedar Grove, Dorchester, Bo...
# 0  Soldiers Field Road, North Brighton, Brighton,...
# 0  Veterans of Foreign Wars Parkway, West Roxbury...
# 0  58, Seaver Street, Roxbury, Boston, Suffolk Co...
# 0  Haul Road, Seaport, South Boston, Boston, Suff...
# 0  Ted Williams Tunnel, Jeffries Point, South Bos...
# 0  I 93, Charlestown, Boston, Suffolk County, Mas...
# 0  4956, Washington Street, Germantown, West Roxb...

# %% [markdown]
# # Saving
#
# Let's save these maps for R.

# %%
## Good practice to refresh your memory

## Find only GeoDataFrames in the current session
geodataframe_list = [var for var in globals() if isinstance(globals()[var], gpd.GeoDataFrame)]

print("List of GeoDataFrames in memory:")
for name in geodataframe_list:
    print(name)
# Out:
# List of GeoDataFrames in memory:
# _
# ___
# boston
# _3
# stations
# _8
# _10
# fuelBoston
# _16
# schools
# schoolBoston
# _21
# secured_schoolBoston
# _33
# fuelBoston_allPoly
# _38
# gas_relocate
# _40
# _41
# streets
# suitable_roads
# secured_fuelBoston_allPoly
# secured_areas_dissolved
# secured_areas
# good_routes_forGas_dissolved
# good_routes_forGas
# _54
# potential_Locations
# candidateStation
# _58
# GoodLocationsGas_buffered_gdf
# GoodLocationsGas_gdf
# GoodLocationsGas_4326
# _63

# %% [markdown]
# These are the ones needed in R:

# %% [markdown]
# The file **europe_8857.gpkg** will keep all those maps as layers!

# %%
boston.to_file("dashboard.gpkg",driver='GPKG',layer='boston')
stations.to_file("dashboard.gpkg",driver='GPKG',layer='stations')
fuelBoston.to_file("dashboard.gpkg",driver='GPKG',layer='fuelBoston')
schoolBoston.to_file("dashboard.gpkg",driver='GPKG',layer='schoolBoston')
secured_schoolBoston.to_file("dashboard.gpkg",driver='GPKG',layer='secured_schoolBoston')
fuelBoston_allPoly.to_file("dashboard.gpkg",driver='GPKG',layer='fuelBoston_allPoly')
gas_relocate.to_file("dashboard.gpkg",driver='GPKG',layer='gas_relocate')
suitable_roads.to_file("dashboard.gpkg",driver='GPKG',layer='suitable_roads')
streets.to_file("dashboard.gpkg",driver='GPKG',layer='streets')
secured_fuelBoston_allPoly.to_file("dashboard.gpkg",driver='GPKG',layer='secured_fuelBoston_allPoly')
good_routes_forGas.to_file("dashboard.gpkg",driver='GPKG',layer='good_routes_forGas')
GoodLocationsGas_buffered_gdf.to_file("dashboard.gpkg",driver='GPKG',layer='GoodLocationsGas_buffered_gdf')
GoodLocationsGas_gdf.to_file("dashboard.gpkg",driver='GPKG',layer='GoodLocationsGas_gdf')
GoodLocationsGas_4326.to_file("dashboard.gpkg",driver='GPKG',layer='GoodLocationsGas_4326')

# %% [markdown]
# Take a look at the [Dashboard](https://spatial-data-analytics-dacss-690d.github.io/HW1-Interactive-Visualization/) & [GitHub](https://github.com/Spatial-Data-Analytics-DACSS-690D/Gas-Station-Relocation-Analysis)
